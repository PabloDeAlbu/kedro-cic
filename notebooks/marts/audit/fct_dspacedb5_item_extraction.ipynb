# %%
df = catalog.load('dm_audit/fct_dspacedb5_item_extraction_window')
df
# Out:
# [04/01/26 12:04:39] INFO     Loading data from dm_audit/fct_dspacedb5_item_extraction_window   ]8;id=854346;file:///root/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=152598;file:///root/kedro-conicet/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                              (SQLTableDataset)...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                   item_hk source_label  \
# 0       b'\x00\x00\x0b\xfe\x96\x8e\x1d\xd85\x1f\x13\xa...       sedici
# 1       b'\x00\x00\x0e\xe2\x87\xc6_&C\x8c&\x15c\x18\xc...       sedici
# 2       b'\x00\x002\xbd\x07\xfd\xf5\xa5\xa4\xe4\x07i\x...       sedici
# 3       b'\x00\x00\xe1\x87\xee\xff\xab#\x89\x1f\r\xc4....       sedici
# 4       b'\x00\x01\x05\xd1\xec\xfeb\xea\x9f\x80\xbf4$\...       sedici
# ...
