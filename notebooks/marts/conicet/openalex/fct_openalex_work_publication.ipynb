# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
brg_openalex_author_institution = catalog.load('dm_openalex/brg_openalex_author_institution')
brg_openalex_work_author = catalog.load('dm_openalex/brg_openalex_work_author')
brg_openalex_work_institution = catalog.load('dm_openalex/brg_openalex_work_institution')
brg_openalex_work_primarytopic = catalog.load('dm_openalex/brg_openalex_work_primarytopic')
brg_openalex_work_topic = catalog.load('dm_openalex/brg_openalex_work_topic')
dim_openalex_author = catalog.load('dm_openalex/dim_openalex_author')
dim_openalex_institution = catalog.load('dm_openalex/dim_openalex_institution')
dim_openalex_topic = catalog.load('dm_openalex/dim_openalex_topic')
dim_openalex_work = catalog.load('dm_openalex/dim_openalex_work')
fct_openalex_work_publication = catalog.load('dm_openalex/fct_openalex_work_publication')

# %%
brg_openalex_author_institution

# %%
brg_openalex_work_author

# %%
brg_openalex_work_institution

# %%
brg_openalex_work_primarytopic

# %%
brg_openalex_work_topic

# %%
dim_openalex_author

# %%
dim_openalex_institution

# %%
dim_openalex_topic

# %%
dim_openalex_work

# %%
fct_openalex_work_publication

# %%
profile = ProfileReport(fct_openalex_work_publication, title="EDA fct_openalex_work_publication")

# %%
# Cuando quieras verlo en la notebook:
profile.to_notebook_iframe()

# %%
author_profile = ProfileReport(dim_openalex_author, title="EDA fct_openalex_work_publication")

# %%
author_profile.to_notebook_iframe()

# %%
institution_profile = ProfileReport(dim_openalex_institution, title="EDA dim_openalex_institution")
topic_profile = ProfileReport(dim_openalex_topic, title="EDA dim_openalex_topic")
work_profile = ProfileReport(dim_openalex_work, title="EDA dim_openalex_work")

# %%
institution_profile.to_notebook_iframe()

# %%
topic_profile.to_notebook_iframe()

# %%
work_profile.to_notebook_iframe()
