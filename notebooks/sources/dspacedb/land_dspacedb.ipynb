# %%
import pandas as pd

# %%
df_bitstream = catalog.load('raw/public/bitstream#parquet')
df_bundle = catalog.load('raw/public/bundle#parquet')
df_bundle2bitstream = catalog.load('raw/public/bundle2bitstream#parquet')
df_collection = catalog.load('raw/public/collection#parquet')
df_collection2item = catalog.load('raw/public/collection2item#parquet')
df_community = catalog.load('raw/public/community#parquet')
df_community2collection = catalog.load('raw/public/community2collection#parquet')
df_community2community = catalog.load('raw/public/community2community#parquet')
df_doi = catalog.load('raw/public/doi#parquet')
df_eperson = catalog.load('raw/public/eperson#parquet')
df_epersongroup = catalog.load('raw/public/epersongroup#parquet')
df_epersongroup2eperson = catalog.load('raw/public/epersongroup2eperson#parquet')
df_group2group = catalog.load('raw/public/group2group#parquet')
df_handle = catalog.load('raw/public/handle#parquet')
df_item = catalog.load('raw/public/item#parquet')
df_item2bundle = catalog.load('raw/public/item2bundle#parquet')
df_metadatafieldregistry = catalog.load('raw/public/metadatafieldregistry#parquet')
df_metadataschemaregistry = catalog.load('raw/public/metadataschemaregistry#parquet')
df_metadatavalue = catalog.load('raw/public/metadatavalue#parquet')

# %%
def land_dspacedb(df_bitstream, df_bundle, df_bundle2bitstream, df_collection, df_collection2item, df_community, df_community2collection, df_community2community, df_doi, df_eperson, df_epersongroup, df_epersongroup2eperson, df_group2group, df_handle, df_item, df_item2bundle, df_metadatafieldregistry, df_metadataschemaregistry, df_metadatavalue):
    return df_bitstream, df_bundle, df_bundle2bitstream, df_collection, df_collection2item, df_community, df_community2collection, df_community2community, df_doi, df_eperson, df_epersongroup, df_epersongroup2eperson, df_group2group, df_handle, df_item, df_item2bundle, df_metadatafieldregistry, df_metadataschemaregistry, df_metadatavalue

# %%
df_bitstream, df_bundle, df_bundle2bitstream, df_collection, df_collection2item, df_community, df_community2collection, df_community2community, df_doi, df_eperson, df_epersongroup, df_epersongroup2eperson, df_group2group, df_handle, df_item, df_item2bundle, df_metadatafieldregistry, df_metadataschemaregistry, df_metadatavalue = land_dspacedb(df_item, df_metadatavalue, df_metadatafieldregistry, df_metadataschemaregistry)

# %%
df_item

# %%
df_metadatavalue
