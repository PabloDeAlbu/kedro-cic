# %% [markdown]
# # load_openaire_researchproduct_originalid
#
# Prototipo del nodo `load_openaire_researchproduct_originalid` del pipeline `load_openaire`. No guarda datasets.

# %%
from datetime import date
import pandas as pd

# %load_ext kedro.ipython

# %%
df_researchproduct_raw = catalog.load('raw/openaire/researchproduct/parquet/researchproduct_dev')
df_researchproduct_raw.head(2)

# %%
def _add_openaire_extracted_metadata(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in _EXTRACTED_META_COLS:
        if col not in df.columns:
            df[col] = pd.NA
    return df

# %%
def _add_openaire_loaded_metadata(df: pd.DataFrame, load_datetime=None) -> pd.DataFrame:
    df = df.copy()
    if load_datetime is None:
        load_datetime = date.today()
    df["_load_datetime"] = load_datetime
    return df

# %%
def load_openaire_researchproduct_originalid(df: pd.DataFrame)-> pd.DataFrame:
    df = _add_openaire_extracted_metadata(df)

    df_research_originalids = df[['id', 'originalIds', *_EXTRACTED_META_COLS]]

    df_research_originalids = df_research_originalids.explode('originalIds').reset_index(drop=True)

    df_research_originalids = _add_openaire_loaded_metadata(df_research_originalids)

    return df_research_originalids

# %%
df_research_originalids = load_openaire_researchproduct_originalid(df_researchproduct_raw)

# %%
pd.DataFrame([{'dataset': 'df_research_originalids', 'rows': len(df_research_originalids), 'columns': len(df_research_originalids.columns)}])

# %%
df_research_originalids.head(2)
