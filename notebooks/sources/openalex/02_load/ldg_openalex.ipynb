# %%
import pandas as pd

df_work = catalog.load('ldg/openalex/work')
# Out:
# [02/21/26 13:02:44] INFO     Loading data from ldg/openalex/work (SQLTableDataset)...          ]8;id=439189;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=507453;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\

# %%
df_work
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    id  \
# 0    https://openalex.org/W2140131090
# 1    https://openalex.org/W2762087180
# 2    https://openalex.org/W2151692850
# 3    https://openalex.org/W2130811469
# 4    https://openalex.org/W4211046286
# ..                                ...
# 195  https://openalex.org/W2937730115
# 196  https://openalex.org/W2158724283
# 197  https://openalex.org/W3030030520
# 198  https://openalex.org/W1989871154
# 199  https://openalex.org/W3095652295
#
#                                                  title  \
# 0    A global overview of drought and heat-induced ...
# 1    Ferroptosis: A Regulated Cell Death Nexus Link...
# 2        TNT, a free program for phylogenetic analysis
# 3    Global effects of land use on local terrestria...
# 4    The ATLAS Experiment at the CERN Large Hadron ...
# ...

# %%
# Celda 1 — overview rápido
df_work.shape, df_work.columns[:10]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (
#     (200, 96),
#     Index(['id', 'title', 'display_name', 'publication_year', 'publication_date',
#        'language', 'type', 'type_crossref', 'countries_distinct_count',
#        'institutions_distinct_count'],
#       dtype='object')
# )
