# %%
import pandas as pd
import json
from datetime import datetime
pd.set_option('display.max_columns', None)

_EXTRACTED_META_COLS = ["_filter_param", "_filter_value", "_extract_datetime"]

def _add_openalex_extracted_metadata(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in _EXTRACTED_META_COLS:
        if col not in df.columns:
            df[col] = pd.NA
    return df

def _add_openalex_loaded_metadata(df: pd.DataFrame, load_datetime=None) -> pd.DataFrame:
    df = df.copy()
    if load_datetime is None:
        load_datetime = datetime.today()
    df["_load_datetime"] = pd.to_datetime(load_datetime)
    return df

# %%
df_work_raw = catalog.load('raw/openalex/work_dev#parquet')
# Out:
# [03/10/26 09:05:33] INFO     Loading data from raw/openalex/work_dev#parquet                   ]8;id=406065;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=87559;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                              (ParquetDataset)...

# %%
df_work_raw.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id  \
# 0  https://openalex.org/W2089852843
# 1  https://openalex.org/W3037375387
# 2  https://openalex.org/W2032143374
#
#                                              doi  \
# 0  https://doi.org/10.1016/s0378-4371(98)00437-3
# 1   https://doi.org/10.1016/j.envint.2020.105876
# 2  https://doi.org/10.1016/s0023-6438(03)00088-4
#
#                                                title  \
# 0  The role of constraints within generalized non...
# 1  Short-term exposure to particulate matter (PM1...
# 2  Antimicrobial activity of essential oils on th...
#
#                                         display_name  publication_year  \
# 0  The role of constraints within generalized non...              1998
# 1  Short-term exposure to particulate matter (PM1...              2020
# 2  Antimicrobial activity of essential oils on th...              2003
#
#   publication_date                                                ids  \
# 0       1998-12-01  {'doi': 'https://doi.org/10.1016/s0378-4371(98...
# 1       2020-06-23  {'doi': 'https://doi.org/10.1016/j.envint.2020...
# 2       2003-11-01  {'doi': 'https://doi.org/10.1016/s0023-6438(03...
#
#   language                                   primary_location     type  \
# 0       en  {'id': 'doi:10.1016/s0378-4371(98)00437-3', 'i...  article
# 1       en  {'id': 'doi:10.1016/j.envint.2020.105876', 'is...   review
# 2       en  {'id': 'doi:10.1016/s0023-6438(03)00088-4', 'i...  article
#
#                  indexed_in  \
# 0                [crossref]
# 1  [crossref, doaj, pubmed]
# 2          [crossref, doaj]
#
#                                          open_access  \
# 0  {'any_repository_has_fulltext': False, 'is_oa'...
# 1  {'any_repository_has_fulltext': True, 'is_oa':...
# 2  {'any_repository_has_fulltext': False, 'is_oa'...
#
#                                          authorships institutions  \
# 0  [{'affiliations': [{'institution_ids': array([...           []
# 1  [{'affiliations': [{'institution_ids': array([...           []
# 2  [{'affiliations': [{'institution_ids': array([...           []
#
#    countries_distinct_count  institutions_distinct_count  \
# 0                         3                            3
# 1                         1                            5
# 2                         1                            4
#
#              corresponding_author_ids  \
# 0  [https://openalex.org/A5051451815]
# 1  [https://openalex.org/A5069680875]
# 2  [https://openalex.org/A5113848554]
#
#                        corresponding_institution_ids  \
# 0                 [https://openalex.org/I4210125245]
# 1  [https://openalex.org/I128590013, https://open...
# 2  [https://openalex.org/I4210122970, https://ope...
#
#                                             apc_list  \
# 0  {'currency': 'USD', 'value': 3320.0, 'value_us...
# 1  {'currency': 'USD', 'value': 3500.0, 'value_us...
# 2  {'currency': 'USD', 'value': 2250.0, 'value_us...
#
#                                             apc_paid     fwci  has_fulltext  \
# 0                                               None  35.9167         False
# 1  {'currency': 'USD', 'value': 3500.0, 'value_us...  37.9044          True
# 2                                               None   1.7764         False
#
#    cited_by_count                     citation_normalized_percentile  \
# 0            1391  {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# 1             723  {'is_in_top_10_percent': True, 'is_in_top_1_pe...
# 2             489  {'is_in_top_10_percent': False, 'is_in_top_1_p...
#
#   cited_by_percentile_year                                             biblio  \
# 0  {'max': 100, 'min': 99}  {'first_page': '534', 'issue': '3-4', 'last_pa...
# 1  {'max': 100, 'min': 99}  {'first_page': '105876', 'issue': None, 'last_...
# 2  {'max': 100, 'min': 99}  {'first_page': '679', 'issue': '7', 'last_page...
#
#    is_retracted  is_paratext  is_xpac  \
# 0         False        False    False
# 1         False        False    False
# 2         False        False    False
#
#                                        primary_topic  \
# 0  {'display_name': 'Statistical Mechanics and En...
# 1  {'display_name': 'Air Quality and Health Impac...
# 2  {'display_name': 'Essential Oils and Antimicro...
#
#                                               topics  \
# 0  [{'display_name': 'Statistical Mechanics and E...
# 1  [{'display_name': 'Air Quality and Health Impa...
# 2  [{'display_name': 'Essential Oils and Antimicr...
#
#                                             keywords  \
# 0  [{'display_name': 'Harmonic oscillator', 'id':...
# 1  [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2  [{'display_name': 'Antimicrobial', 'id': 'http...
#
#                                             concepts  \
# 0  [{'display_name': 'Harmonic oscillator', 'id':...
# 1  [{'display_name': 'Nitrogen dioxide', 'id': 'h...
# 2  [{'display_name': 'Antimicrobial', 'id': 'http...
#
#                                                 mesh  locations_count  \
# 0                                                 []                1
# 1  [{'descriptor_name': 'Air Pollutants', 'descri...                4
# 2                                                 []                1
#
#                                            locations  \
# 0  [{'id': 'doi:10.1016/s0378-4371(98)00437-3', '...
# 1  [{'id': 'doi:10.1016/j.envint.2020.105876', 'i...
# 2  [{'id': 'doi:10.1016/s0023-6438(03)00088-4', '...
#
#                                     best_oa_location  \
# 0                                               None
# 1  {'id': 'doi:10.1016/j.envint.2020.105876', 'is...
# 2                                               None
#
#                        sustainable_development_goals awards  \
# 0  [{'display_name': 'Affordable and clean energy...     []
# 1  [{'display_name': 'Good health and well-being'...     []
# 2                                                 []     []
#
#                                              funders  \
# 0  [{'display_name': 'Conselho Nacional de Desenv...
# 1  [{'display_name': 'U.S. Environmental Protecti...
# 2                                                 []
#
#                            has_content  \
# 0  {'grobid_xml': False, 'pdf': False}
# 1    {'grobid_xml': True, 'pdf': True}
# 2  {'grobid_xml': False, 'pdf': False}
#
#                                         content_urls  referenced_works_count  \
# 0                                               None                      75
# 1  {'grobid_xml': 'https://content.openalex.org/w...                      90
# 2                                               None                      41
#
#                                     referenced_works  \
# 0  [https://openalex.org/W4839462, https://openal...
# 1  [https://openalex.org/W646356122, https://open...
# 2  [https://openalex.org/W102433214, https://open...
#
#                                        related_works abstract_inverted_index  \
# 0  [https://openalex.org/W2510367851, https://ope...                    None
# 1  [https://openalex.org/W2912161332, https://ope...                    None
# 2  [https://openalex.org/W2553161426, https://ope...                    None
#
#                                       counts_by_year  \
# 0  [{'cited_by_count': 10, 'year': 2026}, {'cited...
# 1  [{'cited_by_count': 12, 'year': 2026}, {'cited...
# 2  [{'cited_by_count': 4, 'year': 2026}, {'cited_...
#
#                  updated_date         created_date     _filter_param  \
# 0  2026-02-25T23:00:34.991745  2025-10-10T00:00:00  institutions.ror
# 1  2026-03-09T08:58:05.943551  2020-07-02T00:00:00  institutions.ror
# 2  2026-02-28T09:26:25.869077  2025-10-10T00:00:00  institutions.ror
#
#                _filter_value _extract_datetime
# 0  https://ror.org/02s7sax82        2026-03-10
# 1  https://ror.org/02s7sax82        2026-03-10
# 2  https://ror.org/02s7sax82        2026-03-10

# %% [markdown]
# # Nodo

# %%
def openalex_load_work(df_work_raw):
    """Limpia y transforma los datos de OpenAlex para su almacenamiento en una base de datos relacional."""

    df_work_raw = _add_openalex_extracted_metadata(df_work_raw)
    
    expected_columns = [
        'id',
        # 'doi', # doi existe en ids
        'title',
        'display_name',
        'publication_year',
        'publication_date',
        'ids',
        'language',
        'primary_location',
        'type',
        'type_crossref',
        # 'indexed_in',
        'open_access',
        # 'authorships',
        # 'institution_assertions',
        'countries_distinct_count',
        'institutions_distinct_count',
        # 'corresponding_author_ids',
        # 'corresponding_institution_ids',
        'apc_list',
        'apc_paid',
        'fwci',
        'has_fulltext',
        'fulltext_origin',
        'cited_by_count',
        'citation_normalized_percentile',
        'cited_by_percentile_year',
        'biblio',
        'is_retracted',
        'is_paratext',
        'primary_topic',
        # 'topics',
        # 'keywords',
        # 'concepts',
        # 'mesh',
        'locations_count',
        # 'locations',
        'best_oa_location',
        # 'sustainable_development_goals',
        # 'grants',
        # 'datasets',
        # 'versions',
        'referenced_works_count',
        # 'referenced_works',
        # 'related_works',
        # 'abstract_inverted_index',
        # 'abstract_inverted_index_v3',
        'cited_by_api_url',
        # 'counts_by_year',
        'updated_date',
        'created_date',
        '_filter_param',
        '_filter_value',
        '_extract_datetime',
    ]

    df_work = df_work_raw.reindex(columns=expected_columns).reset_index(drop=True).copy()

    # Agregar columnas faltantes con NaN
    for col in expected_columns:
        if col not in df_work.columns:
            df_work[col] = pd.NA

    # ids
    df_ids = pd.json_normalize(df_work['ids']).reset_index(drop=True)
    df_work = pd.concat([df_work, df_ids], axis=1)
    df_work.drop(columns=['ids'], inplace=True)    

    # primary_location
    df_primary_location = pd.json_normalize(df_work['primary_location']).reset_index(drop=True)
    df_primary_location.rename(columns=lambda col: f'primary_location.{col}', inplace=True)
    df_primary_location.drop(columns=[
        'primary_location.source',
        'primary_location.source.issn',
        'primary_location.source.host_organization_lineage',
        'primary_location.source.host_organization_lineage_names'
        ],
        inplace=True,
        errors='ignore')

    df_work = pd.concat([df_work, df_primary_location], axis=1)
    df_work.drop(columns=['primary_location'], inplace=True)    

    # openacess
    df_openaccess_expanded = pd.json_normalize(df_work['open_access'])
    df_work = pd.concat([df_work, df_openaccess_expanded], axis=1)
    df_work.drop(columns=['open_access'], inplace=True)    

    # apc_list
    df_apc_list = pd.json_normalize(df_work['apc_list'])
    df_apc_list.rename(columns=lambda col: f'apc_list.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_list], axis=1)
    df_work.drop(columns=['apc_list'], inplace=True)    
 
    # apc_paid
    df_apc_paid = pd.json_normalize(df_work['apc_paid'])
    df_apc_paid.rename(columns=lambda col: f'apc_paid.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_paid], axis=1)
    df_work.drop(columns=['apc_paid'], inplace=True)    
 
    # citation_normalized_percentile
    df_citation_normalized_percentile = pd.json_normalize(df_work['citation_normalized_percentile'])
    df_citation_normalized_percentile.rename(columns=lambda col: f'citation_normalized_percentile.{col}', inplace=True)
    df_work = pd.concat([df_work, df_citation_normalized_percentile], axis=1)
    df_work.drop(columns=['citation_normalized_percentile'], inplace=True)    

    # cited_by_percentile_year
    df_cited_by_percentile_year = pd.json_normalize(df_work['cited_by_percentile_year'])
    df_cited_by_percentile_year.rename(columns=lambda col: f'cited_by_percentile_year.{col}', inplace=True)
    df_work = pd.concat([df_work, df_cited_by_percentile_year], axis=1)
    df_work.drop(columns=['cited_by_percentile_year'], inplace=True)    

    # biblio
    df_biblio = pd.json_normalize(df_work['biblio'])
    df_biblio.rename(columns=lambda col: f'biblio.{col}', inplace=True)
    df_work = pd.concat([df_work, df_biblio], axis=1)
    df_work.drop(columns=['biblio'], inplace=True)

    # primary_topic
    df_primary_topic = pd.json_normalize(df_work['primary_topic'])
    df_primary_topic.rename(columns=lambda col: f'primary_topic.{col}', inplace=True)
    df_work = pd.concat([df_work, df_primary_topic], axis=1)
    df_work.drop(columns=['primary_topic'], inplace=True)    

    # best_oa_location
    df_best_oa_location = pd.json_normalize(df_work['best_oa_location'])
    df_best_oa_location.rename(columns=lambda col: f'best_oa_location.{col}', inplace=True)
    df_best_oa_location.drop(columns=[
        'best_oa_location.source.host_organization_lineage',
        'best_oa_location.source.host_organization_lineage_names',
        'best_oa_location.source.issn',
    ], inplace=True, errors='ignore')
    
    df_work = pd.concat([df_work, df_best_oa_location], axis=1)
    df_work.drop(columns=['best_oa_location'], inplace=True)    

    df_work = _add_openalex_loaded_metadata(df_work)

    # Convertir tipos de datos automáticamente
    df_work = df_work.convert_dtypes()

    return df_work

# %% [markdown]
# ## Ejecuto Nodo

# %%
df_work = openalex_load_work(df_work_raw)

# %% [markdown]
# # Resultados

# %%
df_work
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    id  \
# 0    https://openalex.org/W2089852843
# 1    https://openalex.org/W3037375387
# 2    https://openalex.org/W2032143374
# 3    https://openalex.org/W2021071494
# 4    https://openalex.org/W2601300492
# ..                                ...
# 195  https://openalex.org/W4401008020
# 196  https://openalex.org/W4225795188
# 197  https://openalex.org/W4327631848
# 198  https://openalex.org/W4365804065
# 199  https://openalex.org/W4392301935
#
#                                                  title  \
# 0    The role of constraints within generalized non...
# 1    Short-term exposure to particulate matter (PM1...
# 2    Antimicrobial activity of essential oils on th...
# 3    Evaluating Bayesian networks’ precision for de...
# 4    Effect of outdoor air pollution on asthma exac...
# ..                                                 ...
# 195  El jabalí y el cerdo silvestre (Sus scrofa) en...
# 196  Spike architecture traits associated with type...
# 197  Citrullinemia is a suitable biomarker for post...
# 198  Diversity of non-marine mollusks in the southe...
# 199  Usefulness of oxidative stress biomarkers in n...
#
#                                           display_name  publication_year  \
# 0    The role of constraints within generalized non...              1998
# 1    Short-term exposure to particulate matter (PM1...              2020
# 2    Antimicrobial activity of essential oils on th...              2003
# 3    Evaluating Bayesian networks’ precision for de...              2005
# 4    Effect of outdoor air pollution on asthma exac...              2017
# ..                                                 ...               ...
# 195  El jabalí y el cerdo silvestre (Sus scrofa) en...              2024
# 196  Spike architecture traits associated with type...              2021
# 197  Citrullinemia is a suitable biomarker for post...              2023
# 198  Diversity of non-marine mollusks in the southe...              2023
# 199  Usefulness of oxidative stress biomarkers in n...              2024
#
#     publication_date language     type  type_crossref  \
# 0         1998-12-01       en  article           <NA>
# 1         2020-06-23       en   review           <NA>
# 2         2003-11-01       en  article           <NA>
# 3         2005-12-28       en  article           <NA>
# 4         2017-03-20       en   review           <NA>
# ..               ...      ...      ...            ...
# 195       2024-07-25       es  article           <NA>
# 196       2021-11-05       en  article           <NA>
# 197       2023-03-17       en  article           <NA>
# 198       2023-01-01       pt  article           <NA>
# 199       2024-02-29       en  article           <NA>
#
#      countries_distinct_count  institutions_distinct_count     fwci  \
# 0                           3                            3  35.9167
# 1                           1                            5  37.9044
# 2                           1                            4   1.7764
# 3                           1                            4  11.0826
# 4                           1                            5  21.3906
# ..                        ...                          ...      ...
# 195                         2                           12   3.3318
# 196                         1                            8   0.8754
# 197                         1                            6   1.1615
# 198                         1                            3   1.7619
# 199                         1                            6     0.84
#
#      has_fulltext  fulltext_origin  cited_by_count  is_retracted  is_paratext  \
# 0           False             <NA>            1391         False        False
# 1            True             <NA>             723         False        False
# 2           False             <NA>             489         False        False
# 3           False             <NA>             439         False        False
# 4            True             <NA>             431         False        False
# ..            ...              ...             ...           ...          ...
# 195         False             <NA>               7         False        False
# 196          True             <NA>               6         False        False
# 197          True             <NA>               6         False        False
# 198         False             <NA>               6         False        False
# 199         False             <NA>               6         False        False
#
#      locations_count  referenced_works_count  cited_by_api_url  \
# 0                  1                      75              <NA>
# 1                  4                      90              <NA>
# 2                  1                      41              <NA>
# 3                  1                      31              <NA>
# 4                  6                      72              <NA>
# ..               ...                     ...               ...
# 195                2                      91              <NA>
# 196                1                      34              <NA>
# 197                2                      40              <NA>
# 198                2                      29              <NA>
# 199                2                      77              <NA>
#
#                    updated_date         created_date     _filter_param  \
# 0    2026-02-25T23:00:34.991745  2025-10-10T00:00:00  institutions.ror
# 1    2026-03-09T08:58:05.943551  2020-07-02T00:00:00  institutions.ror
# 2    2026-02-28T09:26:25.869077  2025-10-10T00:00:00  institutions.ror
# 3    2026-03-09T08:58:05.943551  2025-10-10T00:00:00  institutions.ror
# 4    2026-03-06T13:50:29.536080  2025-10-10T00:00:00  institutions.ror
# ..                          ...                  ...               ...
# 195  2025-11-06T03:46:38.306776  2025-10-10T00:00:00  institutions.ror
# 196  2025-11-06T03:46:38.306776  2025-10-10T00:00:00  institutions.ror
# 197  2026-03-05T09:29:38.588285  2025-10-10T00:00:00  institutions.ror
# 198  2026-01-20T17:24:06.736184  2025-10-10T00:00:00  institutions.ror
# 199  2026-03-09T08:58:05.943551  2025-10-10T00:00:00  institutions.ror
#
#                  _filter_value _extract_datetime  \
# 0    https://ror.org/02s7sax82        2026-03-10
# 1    https://ror.org/02s7sax82        2026-03-10
# 2    https://ror.org/02s7sax82        2026-03-10
# 3    https://ror.org/02s7sax82        2026-03-10
# 4    https://ror.org/02s7sax82        2026-03-10
# ..                         ...               ...
# 195  https://ror.org/02s7sax82        2026-03-10
# 196  https://ror.org/02s7sax82        2026-03-10
# 197  https://ror.org/02s7sax82        2026-03-10
# 198  https://ror.org/02s7sax82        2026-03-10
# 199  https://ror.org/02s7sax82        2026-03-10
#
#                                                    doi         mag  \
# 0        https://doi.org/10.1016/s0378-4371(98)00437-3  2089852843
# 1         https://doi.org/10.1016/j.envint.2020.105876  3037375387
# 2        https://doi.org/10.1016/s0023-6438(03)00088-4  2032143374
# 3        https://doi.org/10.1016/j.compedu.2005.11.017  2021071494
# 4         https://doi.org/10.1371/journal.pone.0174050  2601300492
# ..                                                 ...         ...
# 195         https://doi.org/10.25260/ea.24.34.2.0.2389        <NA>
# 196         https://doi.org/10.1007/s10681-021-02936-3        <NA>
# 197           https://doi.org/10.2460/javma.22.12.0543        <NA>
# 198      https://doi.org/10.1590/0001-3765202320220212        <NA>
# 199  https://doi.org/10.1016/j.chemosphere.2024.141578        <NA>
#
#                              openalex  \
# 0    https://openalex.org/W2089852843
# 1    https://openalex.org/W3037375387
# 2    https://openalex.org/W2032143374
# 3    https://openalex.org/W2021071494
# 4    https://openalex.org/W2601300492
# ..                                ...
# 195  https://openalex.org/W4401008020
# 196  https://openalex.org/W4225795188
# 197  https://openalex.org/W4327631848
# 198  https://openalex.org/W4365804065
# 199  https://openalex.org/W4392301935
#
#                                          pmid  \
# 0                                        <NA>
# 1    https://pubmed.ncbi.nlm.nih.gov/32590284
# 2                                        <NA>
# 3                                        <NA>
# 4    https://pubmed.ncbi.nlm.nih.gov/28319180
# ..                                        ...
# 195                                      <NA>
# 196                                      <NA>
# 197  https://pubmed.ncbi.nlm.nih.gov/36933207
# 198  https://pubmed.ncbi.nlm.nih.gov/37075353
# 199  https://pubmed.ncbi.nlm.nih.gov/38430938
#
#                        primary_location.id  primary_location.is_accepted  \
# 0        doi:10.1016/s0378-4371(98)00437-3                          True
# 1         doi:10.1016/j.envint.2020.105876                          True
# 2        doi:10.1016/s0023-6438(03)00088-4                          True
# 3        doi:10.1016/j.compedu.2005.11.017                          True
# 4         doi:10.1371/journal.pone.0174050                          True
# ..                                     ...                           ...
# 195         doi:10.25260/ea.24.34.2.0.2389                          True
# 196         doi:10.1007/s10681-021-02936-3                          True
# 197           doi:10.2460/javma.22.12.0543                          True
# 198      doi:10.1590/0001-3765202320220212                          True
# 199  doi:10.1016/j.chemosphere.2024.141578                          True
#
#      primary_location.is_oa  primary_location.is_published  \
# 0                     False                           True
# 1                      True                           True
# 2                     False                           True
# 3                     False                           True
# 4                      True                           True
# ..                      ...                            ...
# 195                    True                           True
# 196                    True                           True
# 197                    True                           True
# 198                    True                           True
# 199                   False                           True
#
#                      primary_location.landing_page_url  \
# 0        https://doi.org/10.1016/s0378-4371(98)00437-3
# 1         https://doi.org/10.1016/j.envint.2020.105876
# 2        https://doi.org/10.1016/s0023-6438(03)00088-4
# 3        https://doi.org/10.1016/j.compedu.2005.11.017
# 4         https://doi.org/10.1371/journal.pone.0174050
# ..                                                 ...
# 195         https://doi.org/10.25260/ea.24.34.2.0.2389
# 196         https://doi.org/10.1007/s10681-021-02936-3
# 197           https://doi.org/10.2460/javma.22.12.0543
# 198      https://doi.org/10.1590/0001-3765202320220212
# 199  https://doi.org/10.1016/j.chemosphere.2024.141578
#
#     primary_location.license                primary_location.license_id  \
# 0                       <NA>                                       <NA>
# 1                cc-by-nc-nd  https://openalex.org/licenses/cc-by-nc-nd
# 2                       <NA>                                       <NA>
# 3                       <NA>                                       <NA>
# 4                      cc-by        https://openalex.org/licenses/cc-by
# ..                       ...                                        ...
# 195                    cc-by        https://openalex.org/licenses/cc-by
# 196                     <NA>                                       <NA>
# 197                     <NA>                                       <NA>
# 198                    cc-by        https://openalex.org/licenses/cc-by
# 199                     <NA>                                       <NA>
#
#                               primary_location.pdf_url  \
# 0                                                 <NA>
# 1    https://ars.els-cdn.com/content/image/1-s2.0-S...
# 2                                                 <NA>
# 3                                                 <NA>
# 4    https://journals.plos.org/plosone/article/file...
# ..                                                 ...
# 195  https://ojs.ecologiaaustral.com.ar/index.php/E...
# 196  https://link.springer.com/content/pdf/10.1007/...
# 197  https://avmajournals.avma.org/downloadpdf/jour...
# 198  https://www.scielo.br/j/aabc/a/Pbh7PdG9kXhpzTv...
# 199                                               <NA>
#
#                       primary_location.raw_source_name  \
# 0    Physica A: Statistical Mechanics and its Appli...
# 1                            Environment International
# 2                    LWT - Food Science and Technology
# 3                            Computers &amp; Education
# 4                                             PLOS ONE
# ..                                                 ...
# 195                                   Ecología Austral
# 196                                          Euphytica
# 197  Journal of the American Veterinary Medical Ass...
# 198           Anais da Academia Brasileira de Ciências
# 199                                        Chemosphere
#
#     primary_location.raw_type primary_location.version  \
# 0             journal-article         publishedVersion
# 1             journal-article         publishedVersion
# 2             journal-article         publishedVersion
# 3             journal-article         publishedVersion
# 4             journal-article         publishedVersion
# ..                        ...                      ...
# 195           journal-article         publishedVersion
# 196           journal-article         publishedVersion
# 197           journal-article         publishedVersion
# 198           journal-article         publishedVersion
# 199           journal-article         publishedVersion
#
#                   primary_location.source.display_name  \
# 0    Physica A Statistical Mechanics and its Applic...
# 1                            Environment International
# 2                                                  LWT
# 3                                Computers & Education
# 4                                             PLoS ONE
# ..                                                 ...
# 195                                   Ecología Austral
# 196                                          Euphytica
# 197  Journal of the American Veterinary Medical Ass...
# 198           Anais da Academia Brasileira de Ciências
# 199                                        Chemosphere
#
#     primary_location.source.host_organization  \
# 0            https://openalex.org/P4310320990
# 1            https://openalex.org/P4310320990
# 2            https://openalex.org/P4310320990
# 3            https://openalex.org/P4310320990
# 4            https://openalex.org/P4310315706
# ..                                        ...
# 195                                      <NA>
# 196          https://openalex.org/P4310319900
# 197          https://openalex.org/P4322545313
# 198          https://openalex.org/P4310312019
# 199          https://openalex.org/P4310320990
#
#     primary_location.source.host_organization_name  \
# 0                                      Elsevier BV
# 1                                      Elsevier BV
# 2                                      Elsevier BV
# 3                                      Elsevier BV
# 4                        Public Library of Science
# ..                                             ...
# 195                                           <NA>
# 196                Springer Science+Business Media
# 197        American Veterinary Medical Association
# 198                  Brazilian Academy of Sciences
# 199                                    Elsevier BV
#
#            primary_location.source.id  primary_location.source.is_core  \
# 0      https://openalex.org/S24688465                             True
# 1     https://openalex.org/S143381477                             True
# 2      https://openalex.org/S26760650                             True
# 3    https://openalex.org/S4210172634                             True
# 4     https://openalex.org/S202381698                             True
# ..                                ...                              ...
# 195  https://openalex.org/S4210192115                            False
# 196   https://openalex.org/S149191589                             True
# 197   https://openalex.org/S161638509                             True
# 198   https://openalex.org/S111086706                             True
# 199   https://openalex.org/S203465130                             True
#
#      primary_location.source.is_in_doaj  primary_location.source.is_oa  \
# 0                                 False                          False
# 1                                  True                           True
# 2                                  True                          False
# 3                                 False                          False
# 4                                  True                           True
# ..                                  ...                            ...
# 195                                True                           True
# 196                               False                          False
# 197                               False                          False
# 198                                True                           True
# 199                               False                          False
#
#     primary_location.source.issn_l primary_location.source.type  \
# 0                        0378-4371                      journal
# 1                        0160-4120                      journal
# 2                        0023-6438                      journal
# 3                        0360-1315                      journal
# 4                        1932-6203                      journal
# ..                             ...                          ...
# 195                      0327-5477                      journal
# 196                      0014-2336                      journal
# 197                      0003-1488                      journal
# 198                      0001-3765                      journal
# 199                      0045-6535                      journal
#
#      any_repository_has_fulltext  is_oa oa_status  \
# 0                          False  False    closed
# 1                           True   True      gold
# 2                          False  False    closed
# 3                          False  False    closed
# 4                           True   True      gold
# ..                           ...    ...       ...
# 195                         True   True   diamond
# 196                        False   True    bronze
# 197                        False   True    bronze
# 198                        False   True   diamond
# 199                        False  False    closed
#
#                                                 oa_url apc_list.currency  \
# 0                                                 <NA>               USD
# 1    https://ars.els-cdn.com/content/image/1-s2.0-S...               USD
# 2                                                 <NA>               USD
# 3                                                 <NA>               USD
# 4    https://journals.plos.org/plosone/article/file...               USD
# ..                                                 ...               ...
# 195  https://ojs.ecologiaaustral.com.ar/index.php/E...              <NA>
# 196  https://link.springer.com/content/pdf/10.1007/...               EUR
# 197  https://avmajournals.avma.org/downloadpdf/jour...              <NA>
# 198  https://www.scielo.br/j/aabc/a/Pbh7PdG9kXhpzTv...              <NA>
# 199                                               <NA>               USD
#
#      apc_list.value  apc_list.value_usd apc_paid.currency  apc_paid.value  \
# 0              3320                3320              <NA>            <NA>
# 1              3500                3500               USD            3500
# 2              2250                2250              <NA>            <NA>
# 3              4220                4220              <NA>            <NA>
# 4              1805                1805               USD            1805
# ..              ...                 ...               ...             ...
# 195            <NA>                <NA>              <NA>            <NA>
# 196            2690                3490              <NA>            <NA>
# 197            <NA>                <NA>              <NA>            <NA>
# 198            <NA>                <NA>              <NA>            <NA>
# 199            3610                3610              <NA>            <NA>
#
#      apc_paid.value_usd  citation_normalized_percentile.is_in_top_10_percent  \
# 0                  <NA>                                               True
# 1                  3500                                               True
# 2                  <NA>                                              False
# 3                  <NA>                                               True
# 4                  1805                                               True
# ..                  ...                                                ...
# 195                <NA>                                               True
# 196                <NA>                                              False
# 197                <NA>                                              False
# 198                <NA>                                              False
# 199                <NA>                                              False
#
#      citation_normalized_percentile.is_in_top_1_percent  \
# 0                                                 True
# 1                                                 True
# 2                                                False
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 195                                              False
# 196                                              False
# 197                                              False
# 198                                              False
# 199                                              False
#
#      citation_normalized_percentile.value  cited_by_percentile_year.max  \
# 0                                0.999101                           100
# 1                                0.998865                           100
# 2                                0.846547                           100
# 3                                0.988101                           100
# 4                                0.998199                           100
# ..                                    ...                           ...
# 195                              0.917087                           100
# 196                              0.806252                           100
# 197                              0.736538                           100
# 198                              0.827119                           100
# 199                              0.649841                           100
#
#      cited_by_percentile_year.min biblio.first_page biblio.issue  \
# 0                              99               534          3-4
# 1                              99            105876         <NA>
# 2                              99               679            7
# 3                              99               794            3
# 4                              97          e0174050            3
# ..                            ...               ...          ...
# 195                            98               401         <NA>
# 196                            94              <NA>           12
# 197                            97               858            6
# 198                            89         e20220212            1
# 199                            94            141578         <NA>
#
#     biblio.last_page biblio.volume  \
# 0                554           261
# 1             105876           142
# 2                684            36
# 3                808            49
# 4           e0174050            12
# ..               ...           ...
# 195              421          <NA>
# 196             <NA>           217
# 197              864           261
# 198        e20220212            95
# 199           141578           353
#
#                         primary_topic.display_name  \
# 0                Statistical Mechanics and Entropy
# 1                   Air Quality and Health Impacts
# 2        Essential Oils and Antimicrobial Activity
# 3        Learning Styles and Cognitive Differences
# 4                   Air Quality and Health Impacts
# ..                                             ...
# 195              Wildlife Ecology and Conservation
# 196             Mycotoxins in Agriculture and Food
# 197                Animal Nutrition and Physiology
# 198                 Mollusks and Parasites Studies
# 199  Pesticide and Herbicide Environmental Studies
#
#                 primary_topic.id  primary_topic.score  \
# 0    https://openalex.org/T12261               0.9998
# 1    https://openalex.org/T10190                  1.0
# 2    https://openalex.org/T10225               0.9999
# 3    https://openalex.org/T11820               0.9988
# 4    https://openalex.org/T10190               0.9999
# ..                           ...                  ...
# 195  https://openalex.org/T10199               0.9977
# 196  https://openalex.org/T10520               0.9999
# 197  https://openalex.org/T10152               0.9973
# 198  https://openalex.org/T12234               0.9966
# 199  https://openalex.org/T11180               0.9999
#
#     primary_topic.domain.display_name         primary_topic.domain.id  \
# 0                   Physical Sciences  https://openalex.org/domains/3
# 1                   Physical Sciences  https://openalex.org/domains/3
# 2                       Life Sciences  https://openalex.org/domains/1
# 3                     Social Sciences  https://openalex.org/domains/2
# 4                   Physical Sciences  https://openalex.org/domains/3
# ..                                ...                             ...
# 195                 Physical Sciences  https://openalex.org/domains/3
# 196                     Life Sciences  https://openalex.org/domains/1
# 197                     Life Sciences  https://openalex.org/domains/1
# 198                     Life Sciences  https://openalex.org/domains/1
# 199                 Physical Sciences  https://openalex.org/domains/3
#
#          primary_topic.field.display_name          primary_topic.field.id  \
# 0                   Physics and Astronomy  https://openalex.org/fields/31
# 1                   Environmental Science  https://openalex.org/fields/23
# 2    Agricultural and Biological Sciences  https://openalex.org/fields/11
# 3                              Psychology  https://openalex.org/fields/32
# 4                   Environmental Science  https://openalex.org/fields/23
# ..                                    ...                             ...
# 195                 Environmental Science  https://openalex.org/fields/23
# 196  Agricultural and Biological Sciences  https://openalex.org/fields/11
# 197  Agricultural and Biological Sciences  https://openalex.org/fields/11
# 198  Agricultural and Biological Sciences  https://openalex.org/fields/11
# 199                 Environmental Science  https://openalex.org/fields/23
#
#           primary_topic.subfield.display_name  \
# 0           Statistical and Nonlinear Physics
# 1          Health, Toxicology and Mutagenesis
# 2                                Food Science
# 3    Developmental and Educational Psychology
# 4          Health, Toxicology and Mutagenesis
# ..                                        ...
# 195                                   Ecology
# 196                             Plant Science
# 197                Animal Science and Zoology
# 198                            Insect Science
# 199                                 Pollution
#
#                primary_topic.subfield.id                best_oa_location.id  \
# 0    https://openalex.org/subfields/3109                               <NA>
# 1    https://openalex.org/subfields/2307   doi:10.1016/j.envint.2020.105876
# 2    https://openalex.org/subfields/1106                               <NA>
# 3    https://openalex.org/subfields/3204                               <NA>
# 4    https://openalex.org/subfields/2307   doi:10.1371/journal.pone.0174050
# ..                                   ...                                ...
# 195  https://openalex.org/subfields/2303     doi:10.25260/ea.24.34.2.0.2389
# 196  https://openalex.org/subfields/1110     doi:10.1007/s10681-021-02936-3
# 197  https://openalex.org/subfields/1103       doi:10.2460/javma.22.12.0543
# 198  https://openalex.org/subfields/1109  doi:10.1590/0001-3765202320220212
# 199  https://openalex.org/subfields/2310                               <NA>
#
#      best_oa_location.is_accepted  best_oa_location.is_oa  \
# 0                            <NA>                    <NA>
# 1                            True                    True
# 2                            <NA>                    <NA>
# 3                            <NA>                    <NA>
# 4                            True                    True
# ..                            ...                     ...
# 195                          True                    True
# 196                          True                    True
# 197                          True                    True
# 198                          True                    True
# 199                          <NA>                    <NA>
#
#      best_oa_location.is_published  \
# 0                             <NA>
# 1                             True
# 2                             <NA>
# 3                             <NA>
# 4                             True
# ..                             ...
# 195                           True
# 196                           True
# 197                           True
# 198                           True
# 199                           <NA>
#
#                  best_oa_location.landing_page_url best_oa_location.license  \
# 0                                             <NA>                     <NA>
# 1     https://doi.org/10.1016/j.envint.2020.105876              cc-by-nc-nd
# 2                                             <NA>                     <NA>
# 3                                             <NA>                     <NA>
# 4     https://doi.org/10.1371/journal.pone.0174050                    cc-by
# ..                                             ...                      ...
# 195     https://doi.org/10.25260/ea.24.34.2.0.2389                    cc-by
# 196     https://doi.org/10.1007/s10681-021-02936-3                     <NA>
# 197       https://doi.org/10.2460/javma.22.12.0543                     <NA>
# 198  https://doi.org/10.1590/0001-3765202320220212                    cc-by
# 199                                           <NA>                     <NA>
#
#                    best_oa_location.license_id  \
# 0                                         <NA>
# 1    https://openalex.org/licenses/cc-by-nc-nd
# 2                                         <NA>
# 3                                         <NA>
# 4          https://openalex.org/licenses/cc-by
# ..                                         ...
# 195        https://openalex.org/licenses/cc-by
# 196                                       <NA>
# 197                                       <NA>
# 198        https://openalex.org/licenses/cc-by
# 199                                       <NA>
#
#                               best_oa_location.pdf_url  \
# 0                                                 <NA>
# 1    https://ars.els-cdn.com/content/image/1-s2.0-S...
# 2                                                 <NA>
# 3                                                 <NA>
# 4    https://journals.plos.org/plosone/article/file...
# ..                                                 ...
# 195  https://ojs.ecologiaaustral.com.ar/index.php/E...
# 196  https://link.springer.com/content/pdf/10.1007/...
# 197  https://avmajournals.avma.org/downloadpdf/jour...
# 198  https://www.scielo.br/j/aabc/a/Pbh7PdG9kXhpzTv...
# 199                                               <NA>
#
#                       best_oa_location.raw_source_name  \
# 0                                                 <NA>
# 1                            Environment International
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                             PLOS ONE
# ..                                                 ...
# 195                                   Ecología Austral
# 196                                          Euphytica
# 197  Journal of the American Veterinary Medical Ass...
# 198           Anais da Academia Brasileira de Ciências
# 199                                               <NA>
#
#     best_oa_location.raw_type best_oa_location.version  \
# 0                        <NA>                     <NA>
# 1             journal-article         publishedVersion
# 2                        <NA>                     <NA>
# 3                        <NA>                     <NA>
# 4             journal-article         publishedVersion
# ..                        ...                      ...
# 195           journal-article         publishedVersion
# 196           journal-article         publishedVersion
# 197           journal-article         publishedVersion
# 198           journal-article         publishedVersion
# 199                      <NA>                     <NA>
#
#                   best_oa_location.source.display_name  \
# 0                                                 <NA>
# 1                            Environment International
# 2                                                 <NA>
# 3                                                 <NA>
# 4                                             PLoS ONE
# ..                                                 ...
# 195                                   Ecología Austral
# 196                                          Euphytica
# 197  Journal of the American Veterinary Medical Ass...
# 198           Anais da Academia Brasileira de Ciências
# 199                                               <NA>
#
#     best_oa_location.source.host_organization  \
# 0                                        <NA>
# 1            https://openalex.org/P4310320990
# 2                                        <NA>
# 3                                        <NA>
# 4            https://openalex.org/P4310315706
# ..                                        ...
# 195                                      <NA>
# 196          https://openalex.org/P4310319900
# 197          https://openalex.org/P4322545313
# 198          https://openalex.org/P4310312019
# 199                                      <NA>
#
#     best_oa_location.source.host_organization_name  \
# 0                                             <NA>
# 1                                      Elsevier BV
# 2                                             <NA>
# 3                                             <NA>
# 4                        Public Library of Science
# ..                                             ...
# 195                                           <NA>
# 196                Springer Science+Business Media
# 197        American Veterinary Medical Association
# 198                  Brazilian Academy of Sciences
# 199                                           <NA>
#
#            best_oa_location.source.id  best_oa_location.source.is_core  \
# 0                                <NA>                             <NA>
# 1     https://openalex.org/S143381477                             True
# 2                                <NA>                             <NA>
# 3                                <NA>                             <NA>
# 4     https://openalex.org/S202381698                             True
# ..                                ...                              ...
# 195  https://openalex.org/S4210192115                            False
# 196   https://openalex.org/S149191589                             True
# 197   https://openalex.org/S161638509                             True
# 198   https://openalex.org/S111086706                             True
# 199                              <NA>                             <NA>
#
#      best_oa_location.source.is_in_doaj  best_oa_location.source.is_oa  \
# 0                                  <NA>                           <NA>
# 1                                  True                           True
# 2                                  <NA>                           <NA>
# 3                                  <NA>                           <NA>
# 4                                  True                           True
# ..                                  ...                            ...
# 195                                True                           True
# 196                               False                          False
# 197                               False                          False
# 198                                True                           True
# 199                                <NA>                           <NA>
#
#     best_oa_location.source.issn_l best_oa_location.source.type  \
# 0                             <NA>                         <NA>
# 1                        0160-4120                      journal
# 2                             <NA>                         <NA>
# 3                             <NA>                         <NA>
# 4                        1932-6203                      journal
# ..                             ...                          ...
# 195                      0327-5477                      journal
# 196                      0014-2336                      journal
# 197                      0003-1488                      journal
# 198                      0001-3765                      journal
# 199                           <NA>                         <NA>
#
#      best_oa_location.source             _load_datetime
# 0                       <NA> 2026-03-10 09:05:34.992635
# 1                       <NA> 2026-03-10 09:05:34.992635
# 2                       <NA> 2026-03-10 09:05:34.992635
# 3                       <NA> 2026-03-10 09:05:34.992635
# 4                       <NA> 2026-03-10 09:05:34.992635
# ..                       ...                        ...
# 195                     <NA> 2026-03-10 09:05:34.992635
# 196                     <NA> 2026-03-10 09:05:34.992635
# 197                     <NA> 2026-03-10 09:05:34.992635
# 198                     <NA> 2026-03-10 09:05:34.992635
# 199                     <NA> 2026-03-10 09:05:34.992635
#
# [200 rows x 98 columns]
