# %%
import pandas as pd
import json
from datetime import datetime
pd.set_option('display.max_columns', None)

_EXTRACTED_META_COLS = ["_filter_param", "_filter_value", "_extract_datetime"]

def _add_openalex_extracted_metadata(df: pd.DataFrame) -> pd.DataFrame:
    df = df.copy()
    for col in _EXTRACTED_META_COLS:
        if col not in df.columns:
            df[col] = pd.NA
    return df

def _add_openalex_loaded_metadata(df: pd.DataFrame, load_datetime=None) -> pd.DataFrame:
    df = df.copy()
    if load_datetime is None:
        load_datetime = datetime.today()
    df["_load_datetime"] = pd.to_datetime(load_datetime)
    return df

# %%
df_work_raw = catalog.load('raw/openalex/work_dev#parquet')
# Out:
# [03/04/26 10:45:03] INFO     Loading data from raw/openalex/work_dev#parquet                   ]8;id=824102;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=425852;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\
#                              (ParquetDataset)...

# %%
df_work_raw.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id  \
# 0  https://openalex.org/W2140131090
# 1  https://openalex.org/W2762087180
# 2  https://openalex.org/W2151692850
#
#                                                 doi  \
# 0      https://doi.org/10.1016/j.foreco.2009.09.001
# 1        https://doi.org/10.1016/j.cell.2017.09.021
# 2  https://doi.org/10.1111/j.1096-0031.2008.00217.x
#
#                                                title  \
# 0  A global overview of drought and heat-induced ...
# 1  Ferroptosis: A Regulated Cell Death Nexus Link...
# 2      TNT, a free program for phylogenetic analysis
#
#                                         display_name  publication_year  \
# 0  A global overview of drought and heat-induced ...              2009
# 1  Ferroptosis: A Regulated Cell Death Nexus Link...              2017
# 2      TNT, a free program for phylogenetic analysis              2008
#
#   publication_date                                                ids  \
# 0       2009-10-22  {'doi': 'https://doi.org/10.1016/j.foreco.2009...
# 1       2017-10-01  {'doi': 'https://doi.org/10.1016/j.cell.2017.0...
# 2       2008-07-11  {'doi': 'https://doi.org/10.1111/j.1096-0031.2...
#
#   language                                   primary_location     type  \
# 0       en  {'id': 'doi:10.1016/j.foreco.2009.09.001', 'is...  article
# 1       en  {'id': 'doi:10.1016/j.cell.2017.09.021', 'is_a...   review
# 2       en  {'id': 'doi:10.1111/j.1096-0031.2008.00217.x',...  article
#
#            indexed_in                                        open_access  \
# 0          [crossref]  {'any_repository_has_fulltext': False, 'is_oa'...
# 1  [crossref, pubmed]  {'any_repository_has_fulltext': True, 'is_oa':...
# 2          [crossref]  {'any_repository_has_fulltext': None, 'is_oa':...
#
#                                          authorships institutions  \
# 0  [{'affiliations': [{'institution_ids': array([...           []
# 1  [{'affiliations': [{'institution_ids': array([...           []
# 2  [{'affiliations': [{'institution_ids': array([...           []
#
#    countries_distinct_count  institutions_distinct_count  \
# 0                        13                           20
# 1                         6                           27
# 2                         3                            3
#
#              corresponding_author_ids  \
# 0  [https://openalex.org/A5070307451]
# 1  [https://openalex.org/A5030207693]
# 2  [https://openalex.org/A5031097809]
#
#                        corresponding_institution_ids  \
# 0  [https://openalex.org/I1286329397, https://ope...
# 1                   [https://openalex.org/I78577930]
# 2  [https://openalex.org/I151201029, https://open...
#
#                                             apc_list apc_paid      fwci  \
# 0  {'currency': 'USD', 'value': 3460.0, 'value_us...     None  103.3212
# 1  {'currency': 'USD', 'value': 10100.0, 'value_u...     None  197.0188
# 2  {'currency': 'USD', 'value': 3810.0, 'value_us...     None  341.7973
#
#    has_fulltext  cited_by_count  \
# 0         False            7460
# 1         False            7041
# 2         False            5294
#
#                       citation_normalized_percentile cited_by_percentile_year  \
# 0  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
# 1  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 89}
# 2  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
#
#                                               biblio  is_retracted  \
# 0  {'first_page': '660', 'issue': '4', 'last_page...         False
# 1  {'first_page': '273', 'issue': '2', 'last_page...         False
# 2  {'first_page': '774', 'issue': '5', 'last_page...         False
#
#    is_paratext  is_xpac                                      primary_topic  \
# 0        False    False  {'display_name': 'Fire effects on ecosystems',...
# 1        False    False  {'display_name': 'Ferroptosis and cancer progn...
# 2        False    False  {'display_name': 'Plant Diversity and Evolutio...
#
#                                               topics  \
# 0  [{'display_name': 'Fire effects on ecosystems'...
# 1  [{'display_name': 'Ferroptosis and cancer prog...
# 2  [{'display_name': 'Plant Diversity and Evoluti...
#
#                                             keywords  \
# 0  [{'display_name': 'Climate change', 'id': 'htt...
# 1  [{'display_name': 'Biology', 'id': 'https://op...
# 2  [{'display_name': 'Scripting language', 'id': ...
#
#                                             concepts  \
# 0  [{'display_name': 'Climate change', 'id': 'htt...
# 1  [{'display_name': 'Biology', 'id': 'https://op...
# 2  [{'display_name': 'Scripting language', 'id': ...
#
#                                                 mesh  locations_count  \
# 0                                                 []                4
# 1  [{'descriptor_name': 'Animals', 'descriptor_ui...                7
# 2                                                 []                4
#
#                                            locations  \
# 0  [{'id': 'doi:10.1016/j.foreco.2009.09.001', 'i...
# 1  [{'id': 'doi:10.1016/j.cell.2017.09.021', 'is_...
# 2  [{'id': 'doi:10.1111/j.1096-0031.2008.00217.x'...
#
#                                     best_oa_location  \
# 0                                               None
# 1  {'id': 'doi:10.1016/j.cell.2017.09.021', 'is_a...
# 2  {'id': 'doi:10.1111/j.1096-0031.2008.00217.x',...
#
#                        sustainable_development_goals  \
# 0  [{'display_name': 'Climate action', 'id': 'htt...
# 1  [{'display_name': 'Good health and well-being'...
# 2                                                 []
#
#                                               awards  \
# 0                                                 []
# 1  [{'display_name': None, 'funder_award_id': 'HL...
# 2                                                 []
#
#                                              funders  \
# 0                                                 []
# 1  [{'display_name': 'Geoffrey Beene Cancer Resea...
# 2                                                 []
#
#                            has_content  \
# 0  {'grobid_xml': False, 'pdf': False}
# 1    {'grobid_xml': True, 'pdf': True}
# 2    {'grobid_xml': True, 'pdf': True}
#
#                                         content_urls  referenced_works_count  \
# 0                                               None                     251
# 1  {'grobid_xml': 'https://content.openalex.org/w...                     115
# 2  {'grobid_xml': 'https://content.openalex.org/w...                      38
#
#                                     referenced_works  \
# 0  [https://openalex.org/W21054777, https://opena...
# 1  [https://openalex.org/W35662498, https://opena...
# 2  [https://openalex.org/W1527858535, https://ope...
#
#                                        related_works  \
# 0  [https://openalex.org/W4210601336, https://ope...
# 1  [https://openalex.org/W3126909309, https://ope...
# 2  [https://openalex.org/W2046765700, https://ope...
#
#                              abstract_inverted_index  \
# 0                                               None
# 1                                               None
# 2  {'"(self-)awareness"': None, '"critical"': Non...
#
#                                       counts_by_year  \
# 0  [{'cited_by_count': 85, 'year': 2026}, {'cited...
# 1  [{'cited_by_count': 190, 'year': 2026}, {'cite...
# 2  [{'cited_by_count': 16, 'year': 2026}, {'cited...
#
#                  updated_date         created_date     _filter_param  \
# 0  2026-02-27T16:54:17.756197  2025-10-10T00:00:00  institutions.ror
# 1  2026-03-03T08:47:05.690250  2025-10-10T00:00:00  institutions.ror
# 2  2026-02-25T23:00:34.991745  2016-06-24T00:00:00  institutions.ror
#
#                _filter_value _extract_datetime
# 0  https://ror.org/03cqe8w59        2026-03-03
# 1  https://ror.org/03cqe8w59        2026-03-03
# 2  https://ror.org/03cqe8w59        2026-03-03

# %% [markdown]
# # Nodo

# %%
def openalex_load_work(df_work_raw):
    """Limpia y transforma los datos de OpenAlex para su almacenamiento en una base de datos relacional."""

    df_work_raw = _add_openalex_extracted_metadata(df_work_raw)
    
    expected_columns = [
        'id',
        # 'doi', # doi existe en ids
        'title',
        'display_name',
        'publication_year',
        'publication_date',
        'ids',
        'language',
        'primary_location',
        'type',
        'type_crossref',
        # 'indexed_in',
        'open_access',
        # 'authorships',
        # 'institution_assertions',
        'countries_distinct_count',
        'institutions_distinct_count',
        # 'corresponding_author_ids',
        # 'corresponding_institution_ids',
        'apc_list',
        'apc_paid',
        'fwci',
        'has_fulltext',
        'fulltext_origin',
        'cited_by_count',
        'citation_normalized_percentile',
        'cited_by_percentile_year',
        'biblio',
        'is_retracted',
        'is_paratext',
        'primary_topic',
        # 'topics',
        # 'keywords',
        # 'concepts',
        # 'mesh',
        'locations_count',
        # 'locations',
        'best_oa_location',
        # 'sustainable_development_goals',
        # 'grants',
        # 'datasets',
        # 'versions',
        'referenced_works_count',
        # 'referenced_works',
        # 'related_works',
        # 'abstract_inverted_index',
        # 'abstract_inverted_index_v3',
        'cited_by_api_url',
        # 'counts_by_year',
        'updated_date',
        'created_date',
        '_filter_param',
        '_filter_value',
        '_extract_datetime',
    ]

    df_work = df_work_raw.reindex(columns=expected_columns).reset_index(drop=True).copy()

    # Agregar columnas faltantes con NaN
    for col in expected_columns:
        if col not in df_work.columns:
            df_work[col] = pd.NA

    # ids
    df_ids = pd.json_normalize(df_work['ids']).reset_index(drop=True)
    df_work = pd.concat([df_work, df_ids], axis=1)
    df_work.drop(columns=['ids'], inplace=True)    

    # primary_location
    df_primary_location = pd.json_normalize(df_work['primary_location']).reset_index(drop=True)
    df_primary_location.rename(columns=lambda col: f'primary_location.{col}', inplace=True)
    df_primary_location.drop(columns=[
        'primary_location.source.issn',
        'primary_location.source.host_organization_lineage',
        'primary_location.source.host_organization_lineage_names'
        ],
        inplace=True)

    df_work = pd.concat([df_work, df_primary_location], axis=1)
    df_work.drop(columns=['primary_location'], inplace=True)    

    # openacess
    df_openaccess_expanded = pd.json_normalize(df_work['open_access'])
    df_work = pd.concat([df_work, df_openaccess_expanded], axis=1)
    df_work.drop(columns=['open_access'], inplace=True)    

    # apc_list
    df_apc_list = pd.json_normalize(df_work['apc_list'])
    df_apc_list.rename(columns=lambda col: f'apc_list.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_list], axis=1)
    df_work.drop(columns=['apc_list'], inplace=True)    
 
    # apc_paid
    df_apc_paid = pd.json_normalize(df_work['apc_paid'])
    df_apc_paid.rename(columns=lambda col: f'apc_paid.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_paid], axis=1)
    df_work.drop(columns=['apc_paid'], inplace=True)    
 
    # citation_normalized_percentile
    df_citation_normalized_percentile = pd.json_normalize(df_work['citation_normalized_percentile'])
    df_citation_normalized_percentile.rename(columns=lambda col: f'citation_normalized_percentile.{col}', inplace=True)
    df_work = pd.concat([df_work, df_citation_normalized_percentile], axis=1)
    df_work.drop(columns=['citation_normalized_percentile'], inplace=True)    

    # cited_by_percentile_year
    df_cited_by_percentile_year = pd.json_normalize(df_work['cited_by_percentile_year'])
    df_cited_by_percentile_year.rename(columns=lambda col: f'cited_by_percentile_year.{col}', inplace=True)
    df_work = pd.concat([df_work, df_cited_by_percentile_year], axis=1)
    df_work.drop(columns=['cited_by_percentile_year'], inplace=True)    

    # biblio
    df_biblio = pd.json_normalize(df_work['biblio'])
    df_biblio.rename(columns=lambda col: f'biblio.{col}', inplace=True)
    df_work = pd.concat([df_work, df_biblio], axis=1)
    df_work.drop(columns=['biblio'], inplace=True)

    # primary_topic
    df_primary_topic = pd.json_normalize(df_work['primary_topic'])
    df_primary_topic.rename(columns=lambda col: f'primary_topic.{col}', inplace=True)
    df_work = pd.concat([df_work, df_primary_topic], axis=1)
    df_work.drop(columns=['primary_topic'], inplace=True)    

    # best_oa_location
    df_best_oa_location = pd.json_normalize(df_work['best_oa_location'])
    df_best_oa_location.rename(columns=lambda col: f'best_oa_location.{col}', inplace=True)
    df_best_oa_location.drop(columns=[
        'best_oa_location.source.host_organization_lineage',
        'best_oa_location.source.host_organization_lineage_names',
        'best_oa_location.source.issn',
    ], inplace=True)
    
    df_work = pd.concat([df_work, df_best_oa_location], axis=1)
    df_work.drop(columns=['best_oa_location'], inplace=True)    

    df_work = _add_openalex_loaded_metadata(df_work)

    # Convertir tipos de datos automáticamente
    df_work = df_work.convert_dtypes()

    return df_work

# %% [markdown]
# ## Ejecuto Nodo

# %%
df_work = openalex_load_work(df_work_raw)

# %% [markdown]
# # Resultados

# %%
df_work
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    id  \
# 0    https://openalex.org/W2140131090
# 1    https://openalex.org/W2762087180
# 2    https://openalex.org/W2151692850
# 3    https://openalex.org/W2130811469
# 4    https://openalex.org/W4293212596
# ..                                ...
# 195  https://openalex.org/W2937730115
# 196  https://openalex.org/W2151941143
# 197  https://openalex.org/W2599251041
# 198  https://openalex.org/W3036911563
# 199  https://openalex.org/W3095652295
#
#                                                  title  \
# 0    A global overview of drought and heat-induced ...
# 1    Ferroptosis: A Regulated Cell Death Nexus Link...
# 2        TNT, a free program for phylogenetic analysis
# 3    Global effects of land use on local terrestria...
# 4    The Astropy Project: Sustaining and Growing a ...
# ..                                                 ...
# 195  The interplay of landscape composition and con...
# 196  Atmospheric nitrogen deposition in world biodi...
# 197  Autoreject: Automated artifact rejection for M...
# 198  Data governance: Organizing data for trustwort...
# 199  Solid Lipid Nanoparticles for Drug Delivery: P...
#
#                                           display_name  publication_year  \
# 0    A global overview of drought and heat-induced ...              2009
# 1    Ferroptosis: A Regulated Cell Death Nexus Link...              2017
# 2        TNT, a free program for phylogenetic analysis              2008
# 3    Global effects of land use on local terrestria...              2015
# 4    The Astropy Project: Sustaining and Growing a ...              2022
# ..                                                 ...               ...
# 195  The interplay of landscape composition and con...              2019
# 196  Atmospheric nitrogen deposition in world biodi...              2006
# 197  Autoreject: Automated artifact rejection for M...              2017
# 198  Data governance: Organizing data for trustwort...              2020
# 199  Solid Lipid Nanoparticles for Drug Delivery: P...              2020
#
#     publication_date language     type  type_crossref  \
# 0         2009-10-22       en  article           <NA>
# 1         2017-10-01       en   review           <NA>
# 2         2008-07-11       en  article           <NA>
# 3         2015-03-31       en  article           <NA>
# 4         2022-01-01       en  article           <NA>
# ..               ...      ...      ...            ...
# 195       2019-04-07       en   letter           <NA>
# 196       2006-03-01       en  article           <NA>
# 197       2017-06-21       en  article           <NA>
# 198       2020-06-21       en  article           <NA>
# 199       2020-10-30       en   review           <NA>
#
#      countries_distinct_count  institutions_distinct_count      fwci  \
# 0                          13                           20  103.3212
# 1                           6                           27  197.0188
# 2                           3                            3  341.7973
# 3                           5                           41  272.7169
# 4                          22                          135  578.3481
# ..                        ...                          ...       ...
# 195                        17                           65  101.4675
# 196                         7                           12   25.5605
# 197                         2                            5   10.3813
# 198                         5                            5   43.9809
# 199                         1                            3   26.4235
#
#      has_fulltext  fulltext_origin  cited_by_count  is_retracted  is_paratext  \
# 0           False             <NA>            7460         False        False
# 1           False             <NA>            7041         False        False
# 2           False             <NA>            5294         False        False
# 3           False             <NA>            4064         False        False
# 4           False             <NA>            4059         False        False
# ..            ...              ...             ...           ...          ...
# 195          True             <NA>             593         False        False
# 196         False             <NA>             589         False        False
# 197         False             <NA>             589         False        False
# 198          True             <NA>             589         False        False
# 199          True             <NA>             589         False        False
#
#      locations_count  referenced_works_count  cited_by_api_url  \
# 0                  4                     251              <NA>
# 1                  7                     115              <NA>
# 2                  4                      38              <NA>
# 3                  8                     389              <NA>
# 4                  9                      57              <NA>
# ..               ...                     ...               ...
# 195               18                      64              <NA>
# 196                3                      37              <NA>
# 197                6                      64              <NA>
# 198                6                      33              <NA>
# 199                6                     242              <NA>
#
#                    updated_date         created_date     _filter_param  \
# 0    2026-02-27T16:54:17.756197  2025-10-10T00:00:00  institutions.ror
# 1    2026-03-03T08:47:05.690250  2025-10-10T00:00:00  institutions.ror
# 2    2026-02-25T23:00:34.991745  2016-06-24T00:00:00  institutions.ror
# 3    2026-03-03T08:47:05.690250  2025-10-10T00:00:00  institutions.ror
# 4    2026-03-03T08:47:05.690250  2025-10-10T00:00:00  institutions.ror
# ..                          ...                  ...               ...
# 195  2026-02-27T16:54:17.756197  2025-10-10T00:00:00  institutions.ror
# 196  2025-11-06T03:46:38.306776  2025-10-10T00:00:00  institutions.ror
# 197  2026-01-13T01:12:25.745995  2025-10-10T00:00:00  institutions.ror
# 198  2026-02-27T16:54:17.756197  2020-06-25T00:00:00  institutions.ror
# 199  2026-03-03T08:47:05.690250  2020-11-09T00:00:00  institutions.ror
#
#                  _filter_value _extract_datetime  \
# 0    https://ror.org/03cqe8w59        2026-03-03
# 1    https://ror.org/03cqe8w59        2026-03-03
# 2    https://ror.org/03cqe8w59        2026-03-03
# 3    https://ror.org/03cqe8w59        2026-03-03
# 4    https://ror.org/03cqe8w59        2026-03-03
# ..                         ...               ...
# 195  https://ror.org/03cqe8w59        2026-03-03
# 196  https://ror.org/03cqe8w59        2026-03-03
# 197  https://ror.org/03cqe8w59        2026-03-03
# 198  https://ror.org/03cqe8w59        2026-03-03
# 199  https://ror.org/03cqe8w59        2026-03-03
#
#                                                   doi         mag  \
# 0        https://doi.org/10.1016/j.foreco.2009.09.001  2140131090
# 1          https://doi.org/10.1016/j.cell.2017.09.021  2762087180
# 2    https://doi.org/10.1111/j.1096-0031.2008.00217.x  2151692850
# 3                 https://doi.org/10.1038/nature14324  2130811469
# 4                                                <NA>        <NA>
# ..                                                ...         ...
# 195                 https://doi.org/10.1111/ele.13265  2937730115
# 196  https://doi.org/10.1111/j.1365-2486.2006.01104.x  2151941143
# 197  https://doi.org/10.1016/j.neuroimage.2017.06.030  2599251041
# 198         https://doi.org/10.1016/j.giq.2020.101493  3036911563
# 199         https://doi.org/10.3389/fmolb.2020.587997  3095652295
#
#                              openalex  \
# 0    https://openalex.org/W2140131090
# 1    https://openalex.org/W2762087180
# 2    https://openalex.org/W2151692850
# 3    https://openalex.org/W2130811469
# 4    https://openalex.org/W4293212596
# ..                                ...
# 195  https://openalex.org/W2937730115
# 196  https://openalex.org/W2151941143
# 197  https://openalex.org/W2599251041
# 198  https://openalex.org/W3036911563
# 199  https://openalex.org/W3095652295
#
#                                          pmid  \
# 0                                        <NA>
# 1    https://pubmed.ncbi.nlm.nih.gov/28985560
# 2                                        <NA>
# 3    https://pubmed.ncbi.nlm.nih.gov/25832402
# 4                                        <NA>
# ..                                        ...
# 195  https://pubmed.ncbi.nlm.nih.gov/30957401
# 196                                      <NA>
# 197  https://pubmed.ncbi.nlm.nih.gov/28645840
# 198                                      <NA>
# 199  https://pubmed.ncbi.nlm.nih.gov/33195435
#
#                                    primary_location.id  \
# 0                     doi:10.1016/j.foreco.2009.09.001
# 1                       doi:10.1016/j.cell.2017.09.021
# 2                 doi:10.1111/j.1096-0031.2008.00217.x
# 3                              doi:10.1038/nature14324
# 4    pmh:oai:pure.qub.ac.uk/portal:openaire/fd0be0d...
# ..                                                 ...
# 195                              doi:10.1111/ele.13265
# 196               doi:10.1111/j.1365-2486.2006.01104.x
# 197               doi:10.1016/j.neuroimage.2017.06.030
# 198                      doi:10.1016/j.giq.2020.101493
# 199                      doi:10.3389/fmolb.2020.587997
#
#      primary_location.is_accepted  primary_location.is_oa  \
# 0                            True                   False
# 1                            True                    True
# 2                            True                    True
# 3                            True                   False
# 4                            True                    True
# ..                            ...                     ...
# 195                          True                    True
# 196                          True                   False
# 197                          True                   False
# 198                          True                    True
# 199                          True                    True
#
#      primary_location.is_published  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
# ..                             ...
# 195                           True
# 196                           True
# 197                           True
# 198                           True
# 199                           True
#
#                      primary_location.landing_page_url  \
# 0         https://doi.org/10.1016/j.foreco.2009.09.001
# 1           https://doi.org/10.1016/j.cell.2017.09.021
# 2     https://doi.org/10.1111/j.1096-0031.2008.00217.x
# 3                  https://doi.org/10.1038/nature14324
# 4    https://pure.qub.ac.uk/en/publications/fd0be0d...
# ..                                                 ...
# 195                  https://doi.org/10.1111/ele.13265
# 196   https://doi.org/10.1111/j.1365-2486.2006.01104.x
# 197   https://doi.org/10.1016/j.neuroimage.2017.06.030
# 198          https://doi.org/10.1016/j.giq.2020.101493
# 199          https://doi.org/10.3389/fmolb.2020.587997
#
#     primary_location.license          primary_location.license_id  \
# 0                       <NA>                                 <NA>
# 1                       <NA>                                 <NA>
# 2                       <NA>                                 <NA>
# 3                       <NA>                                 <NA>
# 4                      cc-by  https://openalex.org/licenses/cc-by
# ..                       ...                                  ...
# 195                     <NA>                                 <NA>
# 196                     <NA>                                 <NA>
# 197                     <NA>                                 <NA>
# 198                     <NA>                                 <NA>
# 199                    cc-by  https://openalex.org/licenses/cc-by
#
#                               primary_location.pdf_url  \
# 0                                                 <NA>
# 1    http://www.cell.com/article/S009286741731070X/pdf
# 2    https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 195  https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 196                                               <NA>
# 197                                               <NA>
# 198  https://www.sciencedirect.com/science/article/...
# 199  https://www.frontiersin.org/articles/10.3389/f...
#
#                       primary_location.raw_source_name  \
# 0                        Forest Ecology and Management
# 1                                                 Cell
# 2                                           Cladistics
# 3                                               Nature
# 4    Paper Authors & Astropy Project Contributors 2...
# ..                                                 ...
# 195                                    Ecology Letters
# 196                              Global Change Biology
# 197                                         NeuroImage
# 198                   Government Information Quarterly
# 199                 Frontiers in Molecular Biosciences
#
#                    primary_location.raw_type primary_location.version  \
# 0                            journal-article         publishedVersion
# 1                            journal-article         publishedVersion
# 2                            journal-article         publishedVersion
# 3                            journal-article         publishedVersion
# 4    info:eu-repo/semantics/publishedVersion         publishedVersion
# ..                                       ...                      ...
# 195                          journal-article         publishedVersion
# 196                          journal-article         publishedVersion
# 197                          journal-article         publishedVersion
# 198                          journal-article         publishedVersion
# 199                          journal-article         publishedVersion
#
#              primary_location.source.display_name  \
# 0                   Forest Ecology and Management
# 1                                            Cell
# 2                                      Cladistics
# 3                                          Nature
# 4    Research Portal (Queen's University Belfast)
# ..                                            ...
# 195                               Ecology Letters
# 196                         Global Change Biology
# 197                                    NeuroImage
# 198              Government Information Quarterly
# 199            Frontiers in Molecular Biosciences
#
#     primary_location.source.host_organization  \
# 0            https://openalex.org/P4310320990
# 1            https://openalex.org/P4310315673
# 2            https://openalex.org/P4310320595
# 3            https://openalex.org/P4310319908
# 4             https://openalex.org/I126231945
# ..                                        ...
# 195          https://openalex.org/P4310320595
# 196          https://openalex.org/P4310320595
# 197          https://openalex.org/P4310320990
# 198          https://openalex.org/P4310320990
# 199          https://openalex.org/P4310320527
#
#     primary_location.source.host_organization_name  \
# 0                                      Elsevier BV
# 1                                       Cell Press
# 2                                            Wiley
# 3                                 Nature Portfolio
# 4                       Queen's University Belfast
# ..                                             ...
# 195                                          Wiley
# 196                                          Wiley
# 197                                    Elsevier BV
# 198                                    Elsevier BV
# 199                                Frontiers Media
#
#            primary_location.source.id  primary_location.source.is_core  \
# 0     https://openalex.org/S195255895                             True
# 1     https://openalex.org/S110447773                             True
# 2      https://openalex.org/S90511721                             True
# 3     https://openalex.org/S137773608                             True
# 4    https://openalex.org/S4306402319                            False
# ..                                ...                              ...
# 195    https://openalex.org/S80967739                             True
# 196    https://openalex.org/S74970393                             True
# 197   https://openalex.org/S103225281                             True
# 198   https://openalex.org/S201710173                             True
# 199  https://openalex.org/S2595797843                             True
#
#      primary_location.source.is_in_doaj  primary_location.source.is_oa  \
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                          False
# 4                                 False                          False
# ..                                  ...                            ...
# 195                               False                          False
# 196                               False                          False
# 197                                True                          False
# 198                               False                          False
# 199                                True                           True
#
#     primary_location.source.issn_l primary_location.source.type  \
# 0                        0378-1127                      journal
# 1                        0092-8674                      journal
# 2                        0748-3007                      journal
# 3                        0028-0836                      journal
# 4                             <NA>                   repository
# ..                             ...                          ...
# 195                      1461-023X                      journal
# 196                      1354-1013                      journal
# 197                      1053-8119                      journal
# 198                      0740-624X                      journal
# 199                      2296-889X                      journal
#
#      any_repository_has_fulltext  is_oa oa_status  \
# 0                          False  False    closed
# 1                           True   True    bronze
# 2                           <NA>   True    bronze
# 3                           True   True     green
# 4                           True   True     green
# ..                           ...    ...       ...
# 195                         True   True    bronze
# 196                         True   True     green
# 197                         True   True     green
# 198                         True   True    bronze
# 199                         True   True      gold
#
#                                                 oa_url apc_list.currency  \
# 0                                                 <NA>               USD
# 1    http://www.cell.com/article/S009286741731070X/pdf               USD
# 2    https://onlinelibrary.wiley.com/doi/pdfdirect/...               USD
# 3    https://durham-repository.worktribe.com/output...               EUR
# 4    https://pure.qub.ac.uk/en/publications/fd0be0d...              <NA>
# ..                                                 ...               ...
# 195  https://onlinelibrary.wiley.com/doi/pdfdirect/...               USD
# 196  https://research.wur.nl/en/publications/atmosp...               USD
# 197                   https://arxiv.org/pdf/1612.08194               USD
# 198  https://www.sciencedirect.com/science/article/...               USD
# 199  https://www.frontiersin.org/articles/10.3389/f...               USD
#
#      apc_list.value  apc_list.value_usd apc_paid.currency  apc_paid.value  \
# 0              3460                3460              <NA>            <NA>
# 1             10100               10100              <NA>            <NA>
# 2              3810                3810              <NA>            <NA>
# 3              9750               11690              <NA>            <NA>
# 4              <NA>                <NA>              <NA>            <NA>
# ..              ...                 ...               ...             ...
# 195            5050                5050              <NA>            <NA>
# 196            4120                4120              <NA>            <NA>
# 197            3450                3450              <NA>            <NA>
# 198            2980                2980              <NA>            <NA>
# 199            2490                2490               USD            2490
#
#      apc_paid.value_usd  citation_normalized_percentile.is_in_top_10_percent  \
# 0                  <NA>                                               True
# 1                  <NA>                                               True
# 2                  <NA>                                               True
# 3                  <NA>                                               True
# 4                  <NA>                                               True
# ..                  ...                                                ...
# 195                <NA>                                               True
# 196                <NA>                                               True
# 197                <NA>                                               True
# 198                <NA>                                               True
# 199                2490                                               True
#
#      citation_normalized_percentile.is_in_top_1_percent  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 195                                               True
# 196                                               True
# 197                                              False
# 198                                               True
# 199                                               True
#
#      citation_normalized_percentile.value  cited_by_percentile_year.max  \
# 0                                0.999837                           100
# 1                                0.999949                           100
# 2                                     1.0                           100
# 3                                0.999966                           100
# 4                                     1.0                           100
# ..                                    ...                           ...
# 195                              0.999794                           100
# 196                              0.996323                           100
# 197                              0.989278                           100
# 198                              0.999317                           100
# 199                              0.999422                           100
#
#      cited_by_percentile_year.min biblio.first_page biblio.issue  \
# 0                              99               660            4
# 1                              89               273            2
# 2                              99               774            5
# 3                              89                45         7545
# 4                              99              <NA>         <NA>
# ..                            ...               ...          ...
# 195                            99              1083            7
# 196                            99               470            3
# 197                            97               417         <NA>
# 198                            97            101493            3
# 199                            89            587997         <NA>
#
#     biblio.last_page biblio.volume                 primary_topic.display_name  \
# 0                684           259                 Fire effects on ecosystems
# 1                285           171           Ferroptosis and cancer prognosis
# 2                786            24              Plant Diversity and Evolution
# 3                 50           520    Ecology and Vegetation Dynamics Studies
# 4               <NA>          <NA>            Gamma-ray bursts and supernovae
# ..               ...           ...                                        ...
# 195             1094            22                   Plant and animal studies
# 196              476            12            Plant responses to elevated CO2
# 197              429           159          EEG and Brain-Computer Interfaces
# 198           101493            37                Data Quality and Management
# 199           587997             7  Advancements in Transdermal Drug Delivery
#
#                 primary_topic.id  primary_topic.score  \
# 0    https://openalex.org/T10555               0.9999
# 1    https://openalex.org/T11297               0.9999
# 2    https://openalex.org/T10385                0.998
# 3    https://openalex.org/T10005               0.9974
# 4    https://openalex.org/T11323               0.9994
# ..                           ...                  ...
# 195  https://openalex.org/T10487               0.9999
# 196  https://openalex.org/T11760                0.998
# 197  https://openalex.org/T10429               0.9997
# 198  https://openalex.org/T11719               0.9993
# 199  https://openalex.org/T10704               0.9991
#
#     primary_topic.domain.display_name         primary_topic.domain.id  \
# 0                   Physical Sciences  https://openalex.org/domains/3
# 1                     Health Sciences  https://openalex.org/domains/4
# 2                       Life Sciences  https://openalex.org/domains/1
# 3                   Physical Sciences  https://openalex.org/domains/3
# 4                   Physical Sciences  https://openalex.org/domains/3
# ..                                ...                             ...
# 195                     Life Sciences  https://openalex.org/domains/1
# 196                     Life Sciences  https://openalex.org/domains/1
# 197                     Life Sciences  https://openalex.org/domains/1
# 198                   Social Sciences  https://openalex.org/domains/2
# 199                     Life Sciences  https://openalex.org/domains/1
#
#                primary_topic.field.display_name  \
# 0                         Environmental Science
# 1                                      Medicine
# 2          Agricultural and Biological Sciences
# 3                         Environmental Science
# 4                         Physics and Astronomy
# ..                                          ...
# 195        Agricultural and Biological Sciences
# 196        Agricultural and Biological Sciences
# 197                                Neuroscience
# 198                           Decision Sciences
# 199  Pharmacology, Toxicology and Pharmaceutics
#
#              primary_topic.field.id  \
# 0    https://openalex.org/fields/23
# 1    https://openalex.org/fields/27
# 2    https://openalex.org/fields/11
# 3    https://openalex.org/fields/23
# 4    https://openalex.org/fields/31
# ..                              ...
# 195  https://openalex.org/fields/11
# 196  https://openalex.org/fields/11
# 197  https://openalex.org/fields/28
# 198  https://openalex.org/fields/18
# 199  https://openalex.org/fields/30
#
#               primary_topic.subfield.display_name  \
# 0                     Global and Planetary Change
# 1              Pulmonary and Respiratory Medicine
# 2    Ecology, Evolution, Behavior and Systematics
# 3               Nature and Landscape Conservation
# 4                      Astronomy and Astrophysics
# ..                                            ...
# 195  Ecology, Evolution, Behavior and Systematics
# 196                                 Plant Science
# 197                        Cognitive Neuroscience
# 198    Management Science and Operations Research
# 199                        Pharmaceutical Science
#
#                primary_topic.subfield.id  \
# 0    https://openalex.org/subfields/2306
# 1    https://openalex.org/subfields/2740
# 2    https://openalex.org/subfields/1105
# 3    https://openalex.org/subfields/2309
# 4    https://openalex.org/subfields/3103
# ..                                   ...
# 195  https://openalex.org/subfields/1105
# 196  https://openalex.org/subfields/1110
# 197  https://openalex.org/subfields/2805
# 198  https://openalex.org/subfields/1803
# 199  https://openalex.org/subfields/3003
#
#                                    best_oa_location.id  \
# 0                                                 <NA>
# 1                       doi:10.1016/j.cell.2017.09.021
# 2                 doi:10.1111/j.1096-0031.2008.00217.x
# 3      pmh:oai:durham-repository.worktribe.com:1209742
# 4    pmh:oai:pure.qub.ac.uk/portal:openaire/fd0be0d...
# ..                                                 ...
# 195                              doi:10.1111/ele.13265
# 196              pmh:oai:library.wur.nl:wurpubs/345732
# 197                       pmh:oai:arXiv.org:1612.08194
# 198                      doi:10.1016/j.giq.2020.101493
# 199                      doi:10.3389/fmolb.2020.587997
#
#      best_oa_location.is_accepted  best_oa_location.is_oa  \
# 0                            <NA>                    <NA>
# 1                            True                    True
# 2                            True                    True
# 3                           False                    True
# 4                            True                    True
# ..                            ...                     ...
# 195                          True                    True
# 196                          True                    True
# 197                         False                    True
# 198                          True                    True
# 199                          True                    True
#
#      best_oa_location.is_published  \
# 0                             <NA>
# 1                             True
# 2                             True
# 3                            False
# 4                             True
# ..                             ...
# 195                           True
# 196                          False
# 197                          False
# 198                           True
# 199                           True
#
#                      best_oa_location.landing_page_url  \
# 0                                                 <NA>
# 1           https://doi.org/10.1016/j.cell.2017.09.021
# 2     https://doi.org/10.1111/j.1096-0031.2008.00217.x
# 3    https://durham-repository.worktribe.com/output...
# 4    https://pure.qub.ac.uk/en/publications/fd0be0d...
# ..                                                 ...
# 195                  https://doi.org/10.1111/ele.13265
# 196  https://research.wur.nl/en/publications/atmosp...
# 197                    http://arxiv.org/abs/1612.08194
# 198          https://doi.org/10.1016/j.giq.2020.101493
# 199          https://doi.org/10.3389/fmolb.2020.587997
#
#     best_oa_location.license          best_oa_location.license_id  \
# 0                       <NA>                                 <NA>
# 1                       <NA>                                 <NA>
# 2                       <NA>                                 <NA>
# 3                      cc-by  https://openalex.org/licenses/cc-by
# 4                      cc-by  https://openalex.org/licenses/cc-by
# ..                       ...                                  ...
# 195                     <NA>                                 <NA>
# 196                     <NA>                                 <NA>
# 197                     <NA>                                 <NA>
# 198                     <NA>                                 <NA>
# 199                    cc-by  https://openalex.org/licenses/cc-by
#
#                               best_oa_location.pdf_url  \
# 0                                                 <NA>
# 1    http://www.cell.com/article/S009286741731070X/pdf
# 2    https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 195  https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 196                                               <NA>
# 197                   https://arxiv.org/pdf/1612.08194
# 198  https://www.sciencedirect.com/science/article/...
# 199  https://www.frontiersin.org/articles/10.3389/f...
#
#                       best_oa_location.raw_source_name  \
# 0                                                 <NA>
# 1                                                 Cell
# 2                                           Cladistics
# 3                                                 <NA>
# 4    Paper Authors & Astropy Project Contributors 2...
# ..                                                 ...
# 195                                    Ecology Letters
# 196                                    ISSN: 1354-1013
# 197
# 198                   Government Information Quarterly
# 199                 Frontiers in Molecular Biosciences
#
#                    best_oa_location.raw_type best_oa_location.version  \
# 0                                       <NA>                     <NA>
# 1                            journal-article         publishedVersion
# 2                            journal-article         publishedVersion
# 3                            Journal Article         submittedVersion
# 4    info:eu-repo/semantics/publishedVersion         publishedVersion
# ..                                       ...                      ...
# 195                          journal-article         publishedVersion
# 196                 Article/Letter to editor          acceptedVersion
# 197                                     text         submittedVersion
# 198                          journal-article         publishedVersion
# 199                          journal-article         publishedVersion
#
#              best_oa_location.source.display_name  \
# 0                                            <NA>
# 1                                            Cell
# 2                                      Cladistics
# 3      Durham Research Online (Durham University)
# 4    Research Portal (Queen's University Belfast)
# ..                                            ...
# 195                               Ecology Letters
# 196          Socio-Environmental Systems Modeling
# 197                    arXiv (Cornell University)
# 198              Government Information Quarterly
# 199            Frontiers in Molecular Biosciences
#
#     best_oa_location.source.host_organization  \
# 0                                        <NA>
# 1            https://openalex.org/P4310315673
# 2            https://openalex.org/P4310320595
# 3             https://openalex.org/I190082696
# 4             https://openalex.org/I126231945
# ..                                        ...
# 195          https://openalex.org/P4310320595
# 196                                      <NA>
# 197           https://openalex.org/I205783295
# 198          https://openalex.org/P4310320990
# 199          https://openalex.org/P4310320527
#
#     best_oa_location.source.host_organization_name  \
# 0                                             <NA>
# 1                                       Cell Press
# 2                                            Wiley
# 3                                Durham University
# 4                       Queen's University Belfast
# ..                                             ...
# 195                                          Wiley
# 196                                           <NA>
# 197                             Cornell University
# 198                                    Elsevier BV
# 199                                Frontiers Media
#
#            best_oa_location.source.id  best_oa_location.source.is_core  \
# 0                                <NA>                             <NA>
# 1     https://openalex.org/S110447773                             True
# 2      https://openalex.org/S90511721                             True
# 3    https://openalex.org/S4306400188                            False
# 4    https://openalex.org/S4306402319                            False
# ..                                ...                              ...
# 195    https://openalex.org/S80967739                             True
# 196  https://openalex.org/S4210201231                             True
# 197  https://openalex.org/S4306400194                            False
# 198   https://openalex.org/S201710173                             True
# 199  https://openalex.org/S2595797843                             True
#
#      best_oa_location.source.is_in_doaj  best_oa_location.source.is_oa  \
# 0                                  <NA>                           <NA>
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                          False
# 4                                 False                          False
# ..                                  ...                            ...
# 195                               False                          False
# 196                               False                           True
# 197                               False                           True
# 198                               False                          False
# 199                                True                           True
#
#     best_oa_location.source.issn_l best_oa_location.source.type  \
# 0                             <NA>                         <NA>
# 1                        0092-8674                      journal
# 2                        0748-3007                      journal
# 3                             <NA>                   repository
# 4                             <NA>                   repository
# ..                             ...                          ...
# 195                      1461-023X                      journal
# 196                      2663-3027                      journal
# 197                           <NA>                   repository
# 198                      0740-624X                      journal
# 199                      2296-889X                      journal
#
#      best_oa_location.source             _load_datetime
# 0                       <NA> 2026-03-04 10:45:04.712647
# 1                       <NA> 2026-03-04 10:45:04.712647
# 2                       <NA> 2026-03-04 10:45:04.712647
# 3                       <NA> 2026-03-04 10:45:04.712647
# 4                       <NA> 2026-03-04 10:45:04.712647
# ..                       ...                        ...
# 195                     <NA> 2026-03-04 10:45:04.712647
# 196                     <NA> 2026-03-04 10:45:04.712647
# 197                     <NA> 2026-03-04 10:45:04.712647
# 198                     <NA> 2026-03-04 10:45:04.712647
# 199                     <NA> 2026-03-04 10:45:04.712647
#
# [200 rows x 98 columns]
