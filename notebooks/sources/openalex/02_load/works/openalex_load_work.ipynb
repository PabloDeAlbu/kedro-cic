# %%
import pandas as pd
import json
from datetime import datetime
pd.set_option('display.max_columns', None)

# %%
df_work_raw = catalog.load('raw/openalex/work#parquet')
# Out:
# [02/21/26 12:19:31] INFO     Loading data from raw/openalex/work#parquet (ParquetDataset)...   ]8;id=462079;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=760739;file:///home/pablo/dev/scholar/kedro-scholar/.venv/lib/python3.10/site-packages/kedro/io/data_catalog.py#1048\1048]8;;\

# %% [markdown]
# # Profiling

# %%
df_work_raw.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['id', 'doi', 'title', 'display_name', 'publication_year',
#        'publication_date', 'ids', 'language', 'primary_location', 'type',
#        'indexed_in', 'open_access', 'authorships', 'institutions',
#        'countries_distinct_count', 'institutions_distinct_count',
#        'corresponding_author_ids', 'corresponding_institution_ids', 'apc_list',
#        'apc_paid', 'fwci', 'has_fulltext', 'cited_by_count',
#        'citation_normalized_percentile', 'cited_by_percentile_year', 'biblio',
#        'is_retracted', 'is_paratext', 'is_xpac', 'primary_topic', 'topics',
#        'keywords', 'concepts', 'mesh', 'locations_count', 'locations',
#        'best_oa_location', 'sustainable_development_goals', 'awards',
#        'funders', 'has_content', 'referenced_works_count', 'referenced_works',
#        'related_works', 'abstract_inverted_index', 'counts_by_year',
#        'updated_date', 'created_date', 'extract_datetime'],
#       dtype='object')

# %%
df_work_raw.head(3)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                  id  \
# 0  https://openalex.org/W2140131090
# 1  https://openalex.org/W2762087180
# 2  https://openalex.org/W2151692850
#
#                                                 doi  \
# 0      https://doi.org/10.1016/j.foreco.2009.09.001
# 1        https://doi.org/10.1016/j.cell.2017.09.021
# 2  https://doi.org/10.1111/j.1096-0031.2008.00217.x
#
#                                                title  \
# 0  A global overview of drought and heat-induced ...
# 1  Ferroptosis: A Regulated Cell Death Nexus Link...
# 2      TNT, a free program for phylogenetic analysis
#
#                                         display_name  publication_year  \
# 0  A global overview of drought and heat-induced ...              2009
# 1  Ferroptosis: A Regulated Cell Death Nexus Link...              2017
# 2      TNT, a free program for phylogenetic analysis              2008
#
#   publication_date                                                ids  \
# 0       2009-10-22  {'doi': 'https://doi.org/10.1016/j.foreco.2009...
# 1       2017-10-01  {'doi': 'https://doi.org/10.1016/j.cell.2017.0...
# 2       2008-07-11  {'doi': 'https://doi.org/10.1111/j.1096-0031.2...
#
#   language                                   primary_location     type  \
# 0       en  {'id': 'doi:10.1016/j.foreco.2009.09.001', 'is...  article
# 1       en  {'id': 'doi:10.1016/j.cell.2017.09.021', 'is_a...   review
# 2       en  {'id': 'doi:10.1111/j.1096-0031.2008.00217.x',...  article
#
#            indexed_in                                        open_access  \
# 0          [crossref]  {'any_repository_has_fulltext': False, 'is_oa'...
# 1  [crossref, pubmed]  {'any_repository_has_fulltext': False, 'is_oa'...
# 2          [crossref]  {'any_repository_has_fulltext': False, 'is_oa'...
#
#                                          authorships institutions  \
# 0  [{'affiliations': [{'institution_ids': array([...           []
# 1  [{'affiliations': [{'institution_ids': array([...           []
# 2  [{'affiliations': [{'institution_ids': array([...           []
#
#    countries_distinct_count  institutions_distinct_count  \
# 0                         9                           20
# 1                         6                           27
# 2                         3                            3
#
#              corresponding_author_ids     corresponding_institution_ids  \
# 0                                  []                                []
# 1  [https://openalex.org/A5030207693]  [https://openalex.org/I78577930]
# 2                                  []                                []
#
#                                             apc_list apc_paid        fwci  \
# 0  {'currency': 'USD', 'value': 3460.0, 'value_us...     None   93.387205
# 1  {'currency': 'USD', 'value': 10100.0, 'value_u...     None  227.560904
# 2  {'currency': 'USD', 'value': 3810.0, 'value_us...     None  204.217212
#
#    has_fulltext  cited_by_count  \
# 0         False            7330
# 1         False            6749
# 2         False            5267
#
#                       citation_normalized_percentile cited_by_percentile_year  \
# 0  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
# 1  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 90}
# 2  {'is_in_top_10_percent': True, 'is_in_top_1_pe...  {'max': 100, 'min': 99}
#
#                                               biblio  is_retracted  \
# 0  {'first_page': '660', 'issue': '4', 'last_page...         False
# 1  {'first_page': '273', 'issue': '2', 'last_page...         False
# 2  {'first_page': '774', 'issue': '5', 'last_page...         False
#
#    is_paratext  is_xpac                                      primary_topic  \
# 0        False    False  {'display_name': 'Fire effects on ecosystems',...
# 1        False    False  {'display_name': 'Ferroptosis and cancer progn...
# 2        False    False  {'display_name': 'Plant Diversity and Evolutio...
#
#                                               topics  \
# 0  [{'display_name': 'Fire effects on ecosystems'...
# 1  [{'display_name': 'Ferroptosis and cancer prog...
# 2  [{'display_name': 'Plant Diversity and Evoluti...
#
#                                             keywords  \
# 0  [{'display_name': 'Climate change', 'id': 'htt...
# 1  [{'display_name': 'Biology', 'id': 'https://op...
# 2  [{'display_name': 'Scripting language', 'id': ...
#
#                                             concepts  \
# 0  [{'display_name': 'Climate change', 'id': 'htt...
# 1  [{'display_name': 'Biology', 'id': 'https://op...
# 2  [{'display_name': 'Scripting language', 'id': ...
#
#                                                 mesh  locations_count  \
# 0                                                 []                4
# 1  [{'descriptor_name': 'Animals', 'descriptor_ui...                6
# 2                                                 []                4
#
#                                            locations  \
# 0  [{'id': 'doi:10.1016/j.foreco.2009.09.001', 'i...
# 1  [{'id': 'doi:10.1016/j.cell.2017.09.021', 'is_...
# 2  [{'id': 'doi:10.1111/j.1096-0031.2008.00217.x'...
#
#                                     best_oa_location  \
# 0  {'id': 'pmh:oai:HAL:hal-00457602v1', 'is_accep...
# 1  {'id': 'doi:10.1016/j.cell.2017.09.021', 'is_a...
# 2  {'id': 'doi:10.1111/j.1096-0031.2008.00217.x',...
#
#                        sustainable_development_goals  \
# 0  [{'display_name': 'Climate action', 'id': 'htt...
# 1  [{'display_name': 'Good health and well-being'...
# 2                                                 []
#
#                                               awards  \
# 0                                                 []
# 1  [{'display_name': None, 'funder_award_id': 'U1...
# 2                                                 []
#
#                                              funders  \
# 0                                                 []
# 1  [{'display_name': 'Geoffrey Beene Cancer Resea...
# 2                                                 []
#
#                            has_content  referenced_works_count  \
# 0  {'grobid_xml': False, 'pdf': False}                     251
# 1    {'grobid_xml': True, 'pdf': True}                     115
# 2    {'grobid_xml': True, 'pdf': True}                      38
#
#                                     referenced_works  \
# 0  [https://openalex.org/W2161828152, https://ope...
# 1  [https://openalex.org/W2258749495, https://ope...
# 2  [https://openalex.org/W2125785852, https://ope...
#
#                                        related_works  \
# 0  [https://openalex.org/W4210601336, https://ope...
# 1  [https://openalex.org/W3126909309, https://ope...
# 2  [https://openalex.org/W2046765700, https://ope...
#
#                              abstract_inverted_index  \
# 0                                               None
# 1                                               None
# 2  {'"critical"': None, '"criticality,"': None, '...
#
#                                       counts_by_year  \
# 0  [{'cited_by_count': 522, 'year': 2025}, {'cite...
# 1  [{'cited_by_count': 1129, 'year': 2025}, {'cit...
# 2  [{'cited_by_count': 148, 'year': 2025}, {'cite...
#
#                  updated_date         created_date extract_datetime
# 0  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-12-15
# 1  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-12-15
# 2  2025-11-06T03:46:38.306776  2016-06-24T00:00:00       2025-12-15

# %%
df_work_raw.dtypes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# id                                 object
# doi                                object
# title                              object
# display_name                       object
# publication_year                    int64
# publication_date                   object
# ids                                object
# language                           object
# primary_location                   object
# type                               object
# indexed_in                         object
# open_access                        object
# authorships                        object
# institutions                       object
# countries_distinct_count            int64
# institutions_distinct_count         int64
# corresponding_author_ids           object
# corresponding_institution_ids      object
# apc_list                           object
# apc_paid                           object
# fwci                              float64
# has_fulltext                         bool
# cited_by_count                      int64
# citation_normalized_percentile     object
# cited_by_percentile_year           object
# biblio                             object
# is_retracted                         bool
# is_paratext                          bool
# is_xpac                              bool
# primary_topic                      object
# topics                             object
# keywords                           object
# concepts                           object
# mesh                               object
# locations_count                     int64
# locations                          object
# best_oa_location                   object
# sustainable_development_goals      object
# awards                             object
# funders                            object
# has_content                        object
# referenced_works_count              int64
# referenced_works                   object
# related_works                      object
# abstract_inverted_index            object
# counts_by_year                     object
# updated_date                       object
# created_date                       object
# extract_datetime                   object
# dtype: object

# %% [markdown]
# # Nodo

# %%
def openalex_load_work(df_work_raw):
    """Limpia y transforma los datos de OpenAlex para su almacenamiento en una base de datos relacional."""
    
    expected_columns = [
        'id',
        # 'doi', # doi existe en ids
        'title',
        'display_name',
        'publication_year',
        'publication_date',
        'ids',
        'language',
        'primary_location',
        'type',
        'type_crossref',
        # 'indexed_in',
        'open_access',
        # 'authorships',
        # 'institution_assertions',
        'countries_distinct_count',
        'institutions_distinct_count',
        # 'corresponding_author_ids',
        # 'corresponding_institution_ids',
        'apc_list',
        'apc_paid',
        'fwci',
        'has_fulltext',
        'fulltext_origin',
        'cited_by_count',
        'citation_normalized_percentile',
        'cited_by_percentile_year',
        'biblio',
        'is_retracted',
        'is_paratext',
        'primary_topic',
        # 'topics',
        # 'keywords',
        # 'concepts',
        # 'mesh',
        'locations_count',
        # 'locations',
        'best_oa_location',
        # 'sustainable_development_goals',
        # 'grants',
        # 'datasets',
        # 'versions',
        'referenced_works_count',
        # 'referenced_works',
        # 'related_works',
        # 'abstract_inverted_index',
        # 'abstract_inverted_index_v3',
        'cited_by_api_url',
        # 'counts_by_year',
        'updated_date',
        'created_date',
        'extract_datetime'
    ]

    df_work = df_work_raw.reindex(columns=expected_columns).reset_index(drop=True).copy()

    # Agregar columnas faltantes con NaN
    for col in expected_columns:
        if col not in df_work.columns:
            df_work[col] = pd.NA

    # ids
    df_ids = pd.json_normalize(df_work['ids']).reset_index(drop=True)
    df_work = pd.concat([df_work, df_ids], axis=1)
    df_work.drop(columns=['ids'], inplace=True)    

    # primary_location
    df_primary_location = pd.json_normalize(df_work['primary_location']).reset_index(drop=True)
    df_primary_location.rename(columns=lambda col: f'primary_location.{col}', inplace=True)
    df_primary_location.drop(columns=[
        'primary_location.source.issn',
        'primary_location.source.host_organization_lineage',
        'primary_location.source.host_organization_lineage_names'
        ],
        inplace=True)

    df_work = pd.concat([df_work, df_primary_location], axis=1)
    df_work.drop(columns=['primary_location'], inplace=True)    

    # openacess
    df_openaccess_expanded = pd.json_normalize(df_work['open_access'])
    df_work = pd.concat([df_work, df_openaccess_expanded], axis=1)
    df_work.drop(columns=['open_access'], inplace=True)    

    # apc_list
    df_apc_list = pd.json_normalize(df_work['apc_list'])
    df_apc_list.rename(columns=lambda col: f'apc_list.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_list], axis=1)
    df_work.drop(columns=['apc_list'], inplace=True)    
 
    # apc_paid
    df_apc_paid = pd.json_normalize(df_work['apc_paid'])
    df_apc_paid.rename(columns=lambda col: f'apc_paid.{col}', inplace=True)
    df_work = pd.concat([df_work, df_apc_paid], axis=1)
    df_work.drop(columns=['apc_paid'], inplace=True)    
 
    # citation_normalized_percentile
    df_citation_normalized_percentile = pd.json_normalize(df_work['citation_normalized_percentile'])
    df_citation_normalized_percentile.rename(columns=lambda col: f'citation_normalized_percentile.{col}', inplace=True)
    df_work = pd.concat([df_work, df_citation_normalized_percentile], axis=1)
    df_work.drop(columns=['citation_normalized_percentile'], inplace=True)    

    # cited_by_percentile_year
    df_cited_by_percentile_year = pd.json_normalize(df_work['cited_by_percentile_year'])
    df_cited_by_percentile_year.rename(columns=lambda col: f'cited_by_percentile_year.{col}', inplace=True)
    df_work = pd.concat([df_work, df_cited_by_percentile_year], axis=1)
    df_work.drop(columns=['cited_by_percentile_year'], inplace=True)    

    # biblio
    df_biblio = pd.json_normalize(df_work['biblio'])
    df_biblio.rename(columns=lambda col: f'biblio.{col}', inplace=True)
    df_work = pd.concat([df_work, df_biblio], axis=1)
    df_work.drop(columns=['biblio'], inplace=True)

    # primary_topic
    df_primary_topic = pd.json_normalize(df_work['primary_topic'])
    df_primary_topic.rename(columns=lambda col: f'primary_topic.{col}', inplace=True)
    df_work = pd.concat([df_work, df_primary_topic], axis=1)
    df_work.drop(columns=['primary_topic'], inplace=True)    

    # best_oa_location
    df_best_oa_location = pd.json_normalize(df_work['best_oa_location'])
    df_best_oa_location.rename(columns=lambda col: f'best_oa_location.{col}', inplace=True)
    df_best_oa_location.drop(columns=[
        'best_oa_location.source.host_organization_lineage',
        'best_oa_location.source.host_organization_lineage_names',
        'best_oa_location.source.issn',
    ], inplace=True)
    
    df_work = pd.concat([df_work, df_best_oa_location], axis=1)
    df_work.drop(columns=['best_oa_location'], inplace=True)    

    # Agregar la fecha de carga con formato datetime
    df_work['_load_datetime'] = pd.to_datetime(datetime.today())

    # Convertir tipos de datos automáticamente
    df_work = df_work.convert_dtypes()

    return df_work

# %% [markdown]
# ## Ejecuto Nodo

# %%
df_work = openalex_load_work(df_work_raw)

# %% [markdown]
# # Resultados

# %%
df_work
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                    id  \
# 0    https://openalex.org/W2140131090
# 1    https://openalex.org/W2762087180
# 2    https://openalex.org/W2151692850
# 3    https://openalex.org/W2130811469
# 4    https://openalex.org/W4211046286
# ..                                ...
# 195  https://openalex.org/W2158724283
# 196  https://openalex.org/W1839088550
# 197  https://openalex.org/W3030030520
# 198  https://openalex.org/W1989871154
# 199  https://openalex.org/W3095652295
#
#                                                  title  \
# 0    A global overview of drought and heat-induced ...
# 1    Ferroptosis: A Regulated Cell Death Nexus Link...
# 2        TNT, a free program for phylogenetic analysis
# 3    Global effects of land use on local terrestria...
# 4    The ATLAS Experiment at the CERN Large Hadron ...
# ..                                                 ...
# 195  Health effects from stratospheric ozone deplet...
# 196               Committing to ecological restoration
# 197  Gender imbalance in medical imaging datasets p...
# 198  Simulations of Galaxy Formation in a Λ Cold Da...
# 199  Solid Lipid Nanoparticles for Drug Delivery: P...
#
#                                           display_name  publication_year  \
# 0    A global overview of drought and heat-induced ...              2009
# 1    Ferroptosis: A Regulated Cell Death Nexus Link...              2017
# 2        TNT, a free program for phylogenetic analysis              2008
# 3    Global effects of land use on local terrestria...              2015
# 4    The ATLAS Experiment at the CERN Large Hadron ...              2008
# ..                                                 ...               ...
# 195  Health effects from stratospheric ozone deplet...              2003
# 196               Committing to ecological restoration              2015
# 197  Gender imbalance in medical imaging datasets p...              2020
# 198  Simulations of Galaxy Formation in a Λ Cold Da...              2003
# 199  Solid Lipid Nanoparticles for Drug Delivery: P...              2020
#
#     publication_date language     type  type_crossref  \
# 0         2009-10-22       en  article           <NA>
# 1         2017-10-01       en   review           <NA>
# 2         2008-07-11       en  article           <NA>
# 3         2015-03-31       en  article           <NA>
# 4         2008-08-14       en  article           <NA>
# ..               ...      ...      ...            ...
# 195       2003-01-01       en   review           <NA>
# 196       2015-05-07       en  article           <NA>
# 197       2020-05-26       en  article           <NA>
# 198       2003-10-17       en  article           <NA>
# 199       2020-10-30       en   review           <NA>
#
#      countries_distinct_count  institutions_distinct_count        fwci  \
# 0                           9                           20   93.387205
# 1                           6                           27  227.560904
# 2                           3                            3  204.217212
# 3                           5                           41   223.54756
# 4                          36                         2048    67.41549
# ..                        ...                          ...         ...
# 195                         6                            8   28.338417
# 196                         4                           13  158.657698
# 197                         1                            5   25.588486
# 198                         5                            8    14.72368
# 199                         1                            3   31.396251
#
#      has_fulltext  fulltext_origin  cited_by_count  is_retracted  is_paratext  \
# 0           False             <NA>            7330         False        False
# 1           False             <NA>            6749         False        False
# 2           False             <NA>            5267         False        False
# 3           False             <NA>            3955         False        False
# 4           False             <NA>            3910         False        False
# ..            ...              ...             ...           ...          ...
# 195         False             <NA>             574         False        False
# 196         False             <NA>             573         False        False
# 197          True             <NA>             572         False        False
# 198         False             <NA>             570         False        False
# 199          True             <NA>             567         False        False
#
#      locations_count  referenced_works_count  cited_by_api_url  \
# 0                  4                     251              <NA>
# 1                  6                     115              <NA>
# 2                  4                      38              <NA>
# 3                  8                     389              <NA>
# 4                 15                     156              <NA>
# ..               ...                     ...               ...
# 195                6                     226              <NA>
# 196                2                      26              <NA>
# 197                3                      38              <NA>
# 198                3                      34              <NA>
# 199                6                     242              <NA>
#
#                    updated_date         created_date extract_datetime  \
# 0    2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-12-15
# 1    2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-12-15
# 2    2025-11-06T03:46:38.306776  2016-06-24T00:00:00       2025-12-15
# 3    2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-12-15
# 4    2025-11-06T03:46:38.306776  2022-02-13T00:00:00       2025-12-15
# ..                          ...                  ...              ...
# 195  2025-11-06T03:46:38.306776  2016-06-24T00:00:00       2025-12-15
# 196  2025-11-06T03:46:38.306776  2016-06-24T00:00:00       2025-12-15
# 197  2025-11-06T03:46:38.306776  2025-10-10T00:00:00       2025-12-15
# 198  2025-11-06T03:46:38.306776  2016-06-24T00:00:00       2025-12-15
# 199  2025-11-06T03:46:38.306776  2020-11-09T00:00:00       2025-12-15
#
#                                                   doi         mag  \
# 0        https://doi.org/10.1016/j.foreco.2009.09.001  2140131090
# 1          https://doi.org/10.1016/j.cell.2017.09.021  2762087180
# 2    https://doi.org/10.1111/j.1096-0031.2008.00217.x  2151692850
# 3                 https://doi.org/10.1038/nature14324  2130811469
# 4       https://doi.org/10.1088/1748-0221/3/08/s08003        <NA>
# ..                                                ...         ...
# 195                  https://doi.org/10.1039/b211159b  2158724283
# 196           https://doi.org/10.1126/science.aaa4216  1839088550
# 197           https://doi.org/10.1073/pnas.1919012117  3030030520
# 198                    https://doi.org/10.1086/378316  1989871154
# 199         https://doi.org/10.3389/fmolb.2020.587997  3095652295
#
#                              openalex  \
# 0    https://openalex.org/W2140131090
# 1    https://openalex.org/W2762087180
# 2    https://openalex.org/W2151692850
# 3    https://openalex.org/W2130811469
# 4    https://openalex.org/W4211046286
# ..                                ...
# 195  https://openalex.org/W2158724283
# 196  https://openalex.org/W1839088550
# 197  https://openalex.org/W3030030520
# 198  https://openalex.org/W1989871154
# 199  https://openalex.org/W3095652295
#
#                                          pmid  \
# 0                                        <NA>
# 1    https://pubmed.ncbi.nlm.nih.gov/28985560
# 2                                        <NA>
# 3    https://pubmed.ncbi.nlm.nih.gov/25832402
# 4                                        <NA>
# ..                                        ...
# 195  https://pubmed.ncbi.nlm.nih.gov/12659537
# 196  https://pubmed.ncbi.nlm.nih.gov/25953995
# 197  https://pubmed.ncbi.nlm.nih.gov/32457147
# 198                                      <NA>
# 199  https://pubmed.ncbi.nlm.nih.gov/33195435
#
#                       primary_location.id  primary_location.is_accepted  \
# 0        doi:10.1016/j.foreco.2009.09.001                          True
# 1          doi:10.1016/j.cell.2017.09.021                          True
# 2    doi:10.1111/j.1096-0031.2008.00217.x                          True
# 3                 doi:10.1038/nature14324                          True
# 4       doi:10.1088/1748-0221/3/08/s08003                          True
# ..                                    ...                           ...
# 195                  doi:10.1039/b211159b                          True
# 196           doi:10.1126/science.aaa4216                          True
# 197           doi:10.1073/pnas.1919012117                          True
# 198                    doi:10.1086/378316                          True
# 199         doi:10.3389/fmolb.2020.587997                          True
#
#      primary_location.is_oa  primary_location.is_published  \
# 0                     False                           True
# 1                      True                           True
# 2                      True                           True
# 3                     False                           True
# 4                     False                           True
# ..                      ...                            ...
# 195                   False                           True
# 196                   False                           True
# 197                    True                           True
# 198                    True                           True
# 199                    True                           True
#
#                     primary_location.landing_page_url  \
# 0        https://doi.org/10.1016/j.foreco.2009.09.001
# 1          https://doi.org/10.1016/j.cell.2017.09.021
# 2    https://doi.org/10.1111/j.1096-0031.2008.00217.x
# 3                 https://doi.org/10.1038/nature14324
# 4       https://doi.org/10.1088/1748-0221/3/08/s08003
# ..                                                ...
# 195                  https://doi.org/10.1039/b211159b
# 196           https://doi.org/10.1126/science.aaa4216
# 197           https://doi.org/10.1073/pnas.1919012117
# 198                    https://doi.org/10.1086/378316
# 199         https://doi.org/10.3389/fmolb.2020.587997
#
#     primary_location.license          primary_location.license_id  \
# 0                       <NA>                                 <NA>
# 1                       <NA>                                 <NA>
# 2                       <NA>                                 <NA>
# 3                       <NA>                                 <NA>
# 4                       <NA>                                 <NA>
# ..                       ...                                  ...
# 195                     <NA>                                 <NA>
# 196                     <NA>                                 <NA>
# 197                    cc-by  https://openalex.org/licenses/cc-by
# 198                     <NA>                                 <NA>
# 199                    cc-by  https://openalex.org/licenses/cc-by
#
#                               primary_location.pdf_url  \
# 0                                                 <NA>
# 1    http://www.cell.com/article/S009286741731070X/pdf
# 2    https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 195                                               <NA>
# 196                                               <NA>
# 197  https://www.pnas.org/content/pnas/117/23/12592...
# 198  https://iopscience.iop.org/article/10.1086/378...
# 199  https://www.frontiersin.org/articles/10.3389/f...
#
#                     primary_location.raw_source_name  \
# 0                      Forest Ecology and Management
# 1                                               Cell
# 2                                         Cladistics
# 3                                             Nature
# 4                         Journal of Instrumentation
# ..                                               ...
# 195     Photochemical &amp; Photobiological Sciences
# 196                                          Science
# 197  Proceedings of the National Academy of Sciences
# 198                        The Astrophysical Journal
# 199               Frontiers in Molecular Biosciences
#
#     primary_location.raw_type primary_location.version  \
# 0             journal-article         publishedVersion
# 1             journal-article         publishedVersion
# 2             journal-article         publishedVersion
# 3             journal-article         publishedVersion
# 4             journal-article         publishedVersion
# ..                        ...                      ...
# 195           journal-article         publishedVersion
# 196           journal-article         publishedVersion
# 197           journal-article         publishedVersion
# 198           journal-article         publishedVersion
# 199           journal-article         publishedVersion
#
#                 primary_location.source.display_name  \
# 0                      Forest Ecology and Management
# 1                                               Cell
# 2                                         Cladistics
# 3                                             Nature
# 4                         Journal of Instrumentation
# ..                                               ...
# 195         Photochemical & Photobiological Sciences
# 196                                          Science
# 197  Proceedings of the National Academy of Sciences
# 198                        The Astrophysical Journal
# 199               Frontiers in Molecular Biosciences
#
#     primary_location.source.host_organization  \
# 0            https://openalex.org/P4310320990
# 1            https://openalex.org/P4310315673
# 2            https://openalex.org/P4310320595
# 3            https://openalex.org/P4310319908
# 4            https://openalex.org/P4310311669
# ..                                        ...
# 195          https://openalex.org/P4310319900
# 196          https://openalex.org/P4310315823
# 197          https://openalex.org/P4310320052
# 198          https://openalex.org/P4310320083
# 199          https://openalex.org/P4310320527
#
#         primary_location.source.host_organization_name  \
# 0                                          Elsevier BV
# 1                                           Cell Press
# 2                                                Wiley
# 3                                     Nature Portfolio
# 4                                 Institute of Physics
# ..                                                 ...
# 195                    Springer Science+Business Media
# 196  American Association for the Advancement of Sc...
# 197                       National Academy of Sciences
# 198                                     IOP Publishing
# 199                                    Frontiers Media
#
#            primary_location.source.id  primary_location.source.is_core  \
# 0     https://openalex.org/S195255895                             True
# 1     https://openalex.org/S110447773                             True
# 2      https://openalex.org/S90511721                             True
# 3     https://openalex.org/S137773608                             True
# 4     https://openalex.org/S116045149                             True
# ..                                ...                              ...
# 195    https://openalex.org/S65504228                             True
# 196     https://openalex.org/S3880285                             True
# 197   https://openalex.org/S125754415                             True
# 198     https://openalex.org/S1980519                             True
# 199  https://openalex.org/S2595797843                             True
#
#      primary_location.source.is_in_doaj  primary_location.source.is_oa  \
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                 False                          False
# 4                                 False                          False
# ..                                  ...                            ...
# 195                               False                          False
# 196                               False                          False
# 197                               False                          False
# 198                                True                          False
# 199                                True                           True
#
#     primary_location.source.issn_l primary_location.source.type  \
# 0                        0378-1127                      journal
# 1                        0092-8674                      journal
# 2                        0748-3007                      journal
# 3                        0028-0836                      journal
# 4                        1748-0221                      journal
# ..                             ...                          ...
# 195                      1474-905X                      journal
# 196                      0036-8075                      journal
# 197                      0027-8424                      journal
# 198                      0004-637X                      journal
# 199                      2296-889X                      journal
#
#      any_repository_has_fulltext  is_oa oa_status  \
# 0                          False   True     green
# 1                          False   True    bronze
# 2                          False   True    bronze
# 3                          False   True      gold
# 4                          False   True     green
# ..                           ...    ...       ...
# 195                        False   True     green
# 196                        False  False    closed
# 197                        False   True    hybrid
# 198                        False   True    bronze
# 199                        False   True      gold
#
#                                                 oa_url apc_list.currency  \
# 0                     https://hal.science/hal-00457602               USD
# 1    http://www.cell.com/article/S009286741731070X/pdf               USD
# 2    https://onlinelibrary.wiley.com/doi/pdfdirect/...               USD
# 3    https://durham-repository.worktribe.com/output...               EUR
# 4                  http://hdl.handle.net/2078.1/138157              <NA>
# ..                                                 ...               ...
# 195                https://lup.lub.lu.se/record/133488               EUR
# 196                                               <NA>              <NA>
# 197  https://www.pnas.org/content/pnas/117/23/12592...              <NA>
# 198  https://iopscience.iop.org/article/10.1086/378...               USD
# 199  https://www.frontiersin.org/articles/10.3389/f...               USD
#
#      apc_list.value  apc_list.value_usd apc_paid.currency  apc_paid.value  \
# 0              3460                3460              <NA>            <NA>
# 1             10100               10100              <NA>            <NA>
# 2              3810                3810              <NA>            <NA>
# 3              9750               11690               EUR            9750
# 4              <NA>                <NA>              <NA>            <NA>
# ..              ...                 ...               ...             ...
# 195            2690                3390              <NA>            <NA>
# 196            <NA>                <NA>              <NA>            <NA>
# 197            <NA>                <NA>              <NA>            <NA>
# 198            4499                4499              <NA>            <NA>
# 199            2490                2490               USD            2490
#
#      apc_paid.value_usd  citation_normalized_percentile.is_in_top_10_percent  \
# 0                  <NA>                                               True
# 1                  <NA>                                               True
# 2                  <NA>                                               True
# 3                 11690                                               True
# 4                  <NA>                                               True
# ..                  ...                                                ...
# 195                <NA>                                               True
# 196                <NA>                                               True
# 197                <NA>                                               True
# 198                <NA>                                               True
# 199                2490                                               True
#
#      citation_normalized_percentile.is_in_top_1_percent  \
# 0                                                 True
# 1                                                 True
# 2                                                 True
# 3                                                 True
# 4                                                 True
# ..                                                 ...
# 195                                               True
# 196                                               True
# 197                                               True
# 198                                               True
# 199                                               True
#
#      citation_normalized_percentile.value  cited_by_percentile_year.max  \
# 0                                0.999836                           100
# 1                                0.999948                           100
# 2                                     1.0                           100
# 3                                0.999966                           100
# 4                                0.999908                           100
# ..                                    ...                           ...
# 195                              0.997353                           100
# 196                              0.999893                           100
# 197                              0.994177                           100
# 198                              0.993944                           100
# 199                              0.999422                           100
#
#      cited_by_percentile_year.min biblio.first_page biblio.issue  \
# 0                              99               660            4
# 1                              90               273            2
# 2                              99               774            5
# 3                              89                45         7545
# 4                              99            S08003           08
# ..                            ...               ...          ...
# 195                            96                29            1
# 196                            89               638         6235
# 197                            90             12592           23
# 198                            99                21            1
# 199                            89            587997         <NA>
#
#     biblio.last_page biblio.volume  \
# 0                684           259
# 1                285           171
# 2                786            24
# 3                 50           520
# 4             S08003             3
# ..               ...           ...
# 195               38             2
# 196              640           348
# 197            12594           117
# 198               34           597
# 199           587997             7
#
#                             primary_topic.display_name  \
# 0                           Fire effects on ecosystems
# 1                     Ferroptosis and cancer prognosis
# 2                        Plant Diversity and Evolution
# 3              Ecology and Vegetation Dynamics Studies
# 4        Particle Detector Development and Performance
# ..                                                 ...
# 195                    Plant responses to elevated CO2
# 196          Environmental Conservation and Management
# 197  Artificial Intelligence in Healthcare and Educ...
# 198          Galaxies: Formation, Evolution, Phenomena
# 199          Advancements in Transdermal Drug Delivery
#
#                 primary_topic.id  primary_topic.score  \
# 0    https://openalex.org/T10555               0.9999
# 1    https://openalex.org/T11297               0.9999
# 2    https://openalex.org/T10385                0.998
# 3    https://openalex.org/T10005               0.9974
# 4    https://openalex.org/T11044                  1.0
# ..                           ...                  ...
# 195  https://openalex.org/T11760               0.9975
# 196  https://openalex.org/T13438               0.9624
# 197  https://openalex.org/T11636               0.9958
# 198  https://openalex.org/T10026               0.9999
# 199  https://openalex.org/T10704               0.9991
#
#     primary_topic.domain.display_name         primary_topic.domain.id  \
# 0                   Physical Sciences  https://openalex.org/domains/3
# 1                     Health Sciences  https://openalex.org/domains/4
# 2                       Life Sciences  https://openalex.org/domains/1
# 3                   Physical Sciences  https://openalex.org/domains/3
# 4                   Physical Sciences  https://openalex.org/domains/3
# ..                                ...                             ...
# 195                     Life Sciences  https://openalex.org/domains/1
# 196                 Physical Sciences  https://openalex.org/domains/3
# 197                   Health Sciences  https://openalex.org/domains/4
# 198                 Physical Sciences  https://openalex.org/domains/3
# 199                     Life Sciences  https://openalex.org/domains/1
#
#                primary_topic.field.display_name  \
# 0                         Environmental Science
# 1                                      Medicine
# 2          Agricultural and Biological Sciences
# 3                         Environmental Science
# 4                         Physics and Astronomy
# ..                                          ...
# 195        Agricultural and Biological Sciences
# 196                       Environmental Science
# 197                                    Medicine
# 198                       Physics and Astronomy
# 199  Pharmacology, Toxicology and Pharmaceutics
#
#              primary_topic.field.id  \
# 0    https://openalex.org/fields/23
# 1    https://openalex.org/fields/27
# 2    https://openalex.org/fields/11
# 3    https://openalex.org/fields/23
# 4    https://openalex.org/fields/31
# ..                              ...
# 195  https://openalex.org/fields/11
# 196  https://openalex.org/fields/23
# 197  https://openalex.org/fields/27
# 198  https://openalex.org/fields/31
# 199  https://openalex.org/fields/30
#
#               primary_topic.subfield.display_name  \
# 0                     Global and Planetary Change
# 1              Pulmonary and Respiratory Medicine
# 2    Ecology, Evolution, Behavior and Systematics
# 3               Nature and Landscape Conservation
# 4                 Nuclear and High Energy Physics
# ..                                            ...
# 195                                 Plant Science
# 196        Management, Monitoring, Policy and Law
# 197                            Health Informatics
# 198                    Astronomy and Astrophysics
# 199                        Pharmaceutical Science
#
#                primary_topic.subfield.id  \
# 0    https://openalex.org/subfields/2306
# 1    https://openalex.org/subfields/2740
# 2    https://openalex.org/subfields/1105
# 3    https://openalex.org/subfields/2309
# 4    https://openalex.org/subfields/3106
# ..                                   ...
# 195  https://openalex.org/subfields/1110
# 196  https://openalex.org/subfields/2308
# 197  https://openalex.org/subfields/2718
# 198  https://openalex.org/subfields/3103
# 199  https://openalex.org/subfields/3003
#
#                                    best_oa_location.id  \
# 0                           pmh:oai:HAL:hal-00457602v1
# 1                       doi:10.1016/j.cell.2017.09.021
# 2                 doi:10.1111/j.1096-0031.2008.00217.x
# 3      pmh:oai:durham-repository.worktribe.com:1209742
# 4              pmh:oai:dial.uclouvain.be:boreal:138157
# ..                                                 ...
# 195  pmh:oai:lup.lub.lu.se:516b4be4-43f7-4469-85c3-...
# 196                                               <NA>
# 197                        doi:10.1073/pnas.1919012117
# 198                                 doi:10.1086/378316
# 199                      doi:10.3389/fmolb.2020.587997
#
#      best_oa_location.is_accepted  best_oa_location.is_oa  \
# 0                           False                    True
# 1                            True                    True
# 2                            True                    True
# 3                           False                    True
# 4                           False                    True
# ..                            ...                     ...
# 195                         False                    True
# 196                          <NA>                    <NA>
# 197                          True                    True
# 198                          True                    True
# 199                          True                    True
#
#      best_oa_location.is_published  \
# 0                            False
# 1                             True
# 2                             True
# 3                            False
# 4                            False
# ..                             ...
# 195                          False
# 196                           <NA>
# 197                           True
# 198                           True
# 199                           True
#
#                      best_oa_location.landing_page_url  \
# 0                     https://hal.science/hal-00457602
# 1           https://doi.org/10.1016/j.cell.2017.09.021
# 2     https://doi.org/10.1111/j.1096-0031.2008.00217.x
# 3    https://durham-repository.worktribe.com/output...
# 4                  http://hdl.handle.net/2078.1/138157
# ..                                                 ...
# 195                https://lup.lub.lu.se/record/133488
# 196                                               <NA>
# 197            https://doi.org/10.1073/pnas.1919012117
# 198                     https://doi.org/10.1086/378316
# 199          https://doi.org/10.3389/fmolb.2020.587997
#
#     best_oa_location.license             best_oa_location.license_id  \
# 0                   other-oa  https://openalex.org/licenses/other-oa
# 1                       <NA>                                    <NA>
# 2                       <NA>                                    <NA>
# 3                      cc-by     https://openalex.org/licenses/cc-by
# 4                   other-oa  https://openalex.org/licenses/other-oa
# ..                       ...                                     ...
# 195                 other-oa  https://openalex.org/licenses/other-oa
# 196                     <NA>                                    <NA>
# 197                    cc-by     https://openalex.org/licenses/cc-by
# 198                     <NA>                                    <NA>
# 199                    cc-by     https://openalex.org/licenses/cc-by
#
#                               best_oa_location.pdf_url  \
# 0                                                 <NA>
# 1    http://www.cell.com/article/S009286741731070X/pdf
# 2    https://onlinelibrary.wiley.com/doi/pdfdirect/...
# 3                                                 <NA>
# 4                                                 <NA>
# ..                                                 ...
# 195                                               <NA>
# 196                                               <NA>
# 197  https://www.pnas.org/content/pnas/117/23/12592...
# 198  https://iopscience.iop.org/article/10.1086/378...
# 199  https://www.frontiersin.org/articles/10.3389/f...
#
#                       best_oa_location.raw_source_name  \
# 0    Forest Ecology and Management, 2010, 259 (4), ...
# 1                                                 Cell
# 2                                           Cladistics
# 3                                                 <NA>
# 4    Journal of Instrumentation, Vol. 3, no.--, p. ...
# ..                                                 ...
# 195                                    ISSN: 1474-9092
# 196                                               <NA>
# 197    Proceedings of the National Academy of Sciences
# 198                          The Astrophysical Journal
# 199                 Frontiers in Molecular Biosciences
#
#           best_oa_location.raw_type best_oa_location.version  \
# 0                  Journal articles         submittedVersion
# 1                   journal-article         publishedVersion
# 2                   journal-article         publishedVersion
# 3                   Journal Article         submittedVersion
# 4    info:eu-repo/semantics/article         submittedVersion
# ..                              ...                      ...
# 195                            text         submittedVersion
# 196                            <NA>                     <NA>
# 197                 journal-article         publishedVersion
# 198                 journal-article         publishedVersion
# 199                 journal-article         publishedVersion
#
#                   best_oa_location.source.display_name  \
# 0    HAL (Le Centre pour la Communication Scientifi...
# 1                                                 Cell
# 2                                           Cladistics
# 3                                                 <NA>
# 4                          Digital Access to Libraries
# ..                                                 ...
# 195     Lund University Publications (Lund University)
# 196                                               <NA>
# 197    Proceedings of the National Academy of Sciences
# 198                          The Astrophysical Journal
# 199                 Frontiers in Molecular Biosciences
#
#     best_oa_location.source.host_organization  \
# 0            https://openalex.org/I1294671590
# 1            https://openalex.org/P4310315673
# 2            https://openalex.org/P4310320595
# 3                                        <NA>
# 4            https://openalex.org/I2800384882
# ..                                        ...
# 195           https://openalex.org/I187531555
# 196                                      <NA>
# 197          https://openalex.org/P4310320052
# 198          https://openalex.org/P4310320083
# 199          https://openalex.org/P4310320527
#
#     best_oa_location.source.host_organization_name  \
# 0     Centre National de la Recherche Scientifique
# 1                                       Cell Press
# 2                                            Wiley
# 3                                             <NA>
# 4                     Harris County Public Library
# ..                                             ...
# 195                                Lund University
# 196                                           <NA>
# 197                   National Academy of Sciences
# 198                                 IOP Publishing
# 199                                Frontiers Media
#
#            best_oa_location.source.id  best_oa_location.source.is_core  \
# 0    https://openalex.org/S4306402512                            False
# 1     https://openalex.org/S110447773                             True
# 2      https://openalex.org/S90511721                             True
# 3                                <NA>                             <NA>
# 4    https://openalex.org/S4306400166                            False
# ..                                ...                              ...
# 195  https://openalex.org/S4306400536                            False
# 196                              <NA>                             <NA>
# 197   https://openalex.org/S125754415                             True
# 198     https://openalex.org/S1980519                             True
# 199  https://openalex.org/S2595797843                             True
#
#      best_oa_location.source.is_in_doaj  best_oa_location.source.is_oa  \
# 0                                 False                          False
# 1                                 False                          False
# 2                                 False                          False
# 3                                  <NA>                           <NA>
# 4                                 False                          False
# ..                                  ...                            ...
# 195                               False                          False
# 196                                <NA>                           <NA>
# 197                               False                          False
# 198                                True                          False
# 199                                True                           True
#
#     best_oa_location.source.issn_l best_oa_location.source.type  \
# 0                             <NA>                   repository
# 1                        0092-8674                      journal
# 2                        0748-3007                      journal
# 3                             <NA>                         <NA>
# 4                             <NA>                   repository
# ..                             ...                          ...
# 195                           <NA>                   repository
# 196                           <NA>                         <NA>
# 197                      0027-8424                      journal
# 198                      0004-637X                      journal
# 199                      2296-889X                      journal
#
#      best_oa_location.source              load_datetime
# 0                       <NA> 2026-02-21 12:19:44.290361
# 1                       <NA> 2026-02-21 12:19:44.290361
# 2                       <NA> 2026-02-21 12:19:44.290361
# 3                       <NA> 2026-02-21 12:19:44.290361
# 4                       <NA> 2026-02-21 12:19:44.290361
# ..                       ...                        ...
# 195                     <NA> 2026-02-21 12:19:44.290361
# 196                     <NA> 2026-02-21 12:19:44.290361
# 197                     <NA> 2026-02-21 12:19:44.290361
# 198                     <NA> 2026-02-21 12:19:44.290361
# 199                     <NA> 2026-02-21 12:19:44.290361
#
# [200 rows x 96 columns]
