# %%
import pandas as pd
from ydata_profiling import ProfileReport

df = catalog.load('stg/openalex/fact_publication_openalex')
profile = ProfileReport(df, title="Perfilamiento de Datos recuperados de OpenAlex - fact_publication")
profile.to_notebook_iframe()  # Genera un reporte interactivo
